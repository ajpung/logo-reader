# %%
# ============================================================
# STEP 1: SYNC NEW IMAGES TO WORKSPACE
# ============================================================

import os
import shutil

COMPONENTS_DIR = './components/'
WORKSPACE_IMG  = './annotation_workspace/images/train'
WORKSPACE_LBL  = './annotation_workspace/labels/train'

os.makedirs(WORKSPACE_IMG, exist_ok=True)
os.makedirs(WORKSPACE_LBL, exist_ok=True)

# Get existing images in workspace
existing_images = set(os.listdir(WORKSPACE_IMG))

# Copy only NEW images
new_count = 0
for f in os.listdir(COMPONENTS_DIR):
    if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
        if f not in existing_images:
            shutil.copy(os.path.join(COMPONENTS_DIR, f), WORKSPACE_IMG)
            new_count += 1

img_count = len([f for f in os.listdir(WORKSPACE_IMG) if f.lower().endswith(('.png','.jpg','.jpeg','.bmp'))])
lbl_count = len([f for f in os.listdir(WORKSPACE_LBL) if f.endswith('.txt')])

print(f"✓ Copied {new_count} new images to workspace")
print(f"✓ Total images:      {img_count}")
print(f"✓ Total annotations: {lbl_count}")
print(f"✓ Remaining to annotate: {img_count - lbl_count}")
# Out:
# ✓ Copied 18 new images to workspace
# ✓ Total images:      3129
# ✓ Total annotations: 3001
# ✓ Remaining to annotate: 128

# %%
# ============================================================
# STEP 2: Enhanced Annotation Tool - Skip Annotated Images
# ============================================================

import tkinter as tk
from PIL import Image, ImageTk
import os

class AnnotationApp:
    def __init__(self, image_dir, label_dir, skip_annotated=True):
        self.image_dir = image_dir
        self.label_dir = label_dir
        self.skip_annotated = skip_annotated
        os.makedirs(label_dir, exist_ok=True)
        
        # Get ALL images
        all_images = sorted([
            f for f in os.listdir(image_dir)
            if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))
        ])
        
        if skip_annotated:
            # ONLY load unannotated images
            self.image_files = []
            for f in all_images:
                label_file = os.path.splitext(f)[0] + '.txt'
                if not os.path.exists(os.path.join(label_dir, label_file)):
                    self.image_files.append(f)
            
            print(f"✓ Loaded {len(self.image_files)} UNANNOTATED images")
            print(f"  (Skipping {len(all_images) - len(self.image_files)} already annotated)")
        else:
            # Load all images, resume from first unannotated
            self.image_files = all_images
            print(f"✓ Loaded {len(self.image_files)} total images")
        
        self.current_idx = 0  # Start at first unannotated
        
        self.box_start = None
        self.box_end = None
        self.dragging = False
        
        self.current_img = None
        self.display_img = None
        self.img_offset_x = 0
        self.img_offset_y = 0
        self.scale = 1.0
        
        self._build_ui()
        self.root.after(100, self._load_image)
        self.root.mainloop()
    
    def _count_annotated(self):
        """Count total annotations in label directory"""
        return len([f for f in os.listdir(self.label_dir) if f.endswith('.txt')])
    
    def _build_ui(self):
        self.root = tk.Tk()
        self.root.title('Logo Annotation Tool')
        self.root.configure(bg='#1e1e1e')
        
        screen_w = self.root.winfo_screenwidth()
        screen_h = self.root.winfo_screenheight()
        win_w = min(900, screen_w - 100)
        win_h = min(950, screen_h - 50)
        self.root.geometry(f'{win_w}x{win_h}')
        self.root.resizable(True, True)
        
        # --- Progress label ---
        self.progress_var = tk.StringVar(value='Loading...')
        tk.Label(
            self.root, textvariable=self.progress_var,
            bg='#1e1e1e', fg='white', font=('Consolas', 11, 'bold')
        ).pack(side='top', pady=(8, 2))
        
        # --- Canvas ---
        canvas_frame = tk.Frame(self.root, bg='#1e1e1e')
        canvas_frame.pack(side='top', fill='both', expand=True, padx=10)
        
        self.canvas = tk.Canvas(canvas_frame, bg='#111111', highlightthickness=0)
        self.canvas.pack(fill='both', expand=True)
        
        self.canvas.bind('<ButtonPress-1>',   self._on_mouse_down)
        self.canvas.bind('<B1-Motion>',       self._on_mouse_drag)
        self.canvas.bind('<ButtonRelease-1>', self._on_mouse_up)
        
        # Keyboard
        self.root.bind('<s>', lambda e: self._save_and_next())
        self.root.bind('<S>', lambda e: self._save_and_next())
        self.root.bind('<n>', lambda e: self._skip())
        self.root.bind('<N>', lambda e: self._skip())
        self.root.bind('<p>', lambda e: self._previous())
        self.root.bind('<P>', lambda e: self._previous())
        
        # --- Buttons ---
        btn_frame = tk.Frame(self.root, bg='#1e1e1e')
        btn_frame.pack(side='bottom', pady=10)
        
        btn_kw = {'font': ('Consolas', 12, 'bold'), 'width': 16,
                  'relief': 'flat', 'cursor': 'hand2', 'bd': 0}
        
        tk.Button(btn_frame, text='✓  Save & Next  [S]',
                  bg='#2ecc71', fg='white', activebackground='#27ae60', activeforeground='white',
                  command=self._save_and_next, **btn_kw
        ).pack(side='left', padx=8)
        
        tk.Button(btn_frame, text='⏭  Skip  [N]',
                  bg='#e67e22', fg='white', activebackground='#d35400', activeforeground='white',
                  command=self._skip, **btn_kw
        ).pack(side='left', padx=8)
        
        tk.Button(btn_frame, text='◀  Previous  [P]',
                  bg='#3498db', fg='white', activebackground='#2980b9', activeforeground='white',
                  command=self._previous, **btn_kw
        ).pack(side='left', padx=8)
        
        # --- Status bar ---
        self.status_var = tk.StringVar(value='Loading...')
        tk.Label(
            self.root, textvariable=self.status_var,
            bg='#2c2c2c', fg='#aaaaaa', font=('Consolas', 9)
        ).pack(side='bottom', fill='x')
    
    def _on_mouse_down(self, event):
        self.box_start = (event.x, event.y)
        self.box_end = None
        self.dragging = True
        self._redraw_canvas()
    
    def _on_mouse_drag(self, event):
        if self.dragging:
            self.box_end = (event.x, event.y)
            self._redraw_canvas()
    
    def _on_mouse_up(self, event):
        self.dragging = False
        if self.box_start and self.box_end:
            if abs(self.box_end[0] - self.box_start[0]) < 5 or \
               abs(self.box_end[1] - self.box_start[1]) < 5:
                self.box_start = None
                self.box_end = None
                self._redraw_canvas()
                return
            self.status_var.set('Box drawn!  Press S or click "Save & Next"')
        self._redraw_canvas()
    
    def _load_image(self):
        if self.current_idx >= len(self.image_files):
            self.progress_var.set('🎉  ALL DONE!')
            total_annotations = self._count_annotated()
            self.status_var.set(f'Finished! Total annotations: {total_annotations}')
            self.canvas.delete('all')
            return
        
        img_file = self.image_files[self.current_idx]
        self.current_img = Image.open(os.path.join(self.image_dir, img_file)).convert('RGB')
        
        # Progress text
        total_annotations = self._count_annotated()
        remaining = len(self.image_files) - self.current_idx
        self.progress_var.set(
            f'[{self.current_idx+1}/{len(self.image_files)}]  {img_file}  |  '
            f'Total annotated: {total_annotations} | Remaining: {remaining}'
        )
        
        # Reset box
        self.box_start = None
        self.box_end = None
        
        # Get actual canvas size
        self.root.update_idletasks()
        canvas_w = self.canvas.winfo_width()
        canvas_h = self.canvas.winfo_height()
        
        if canvas_w <= 1 or canvas_h <= 1:
            canvas_w = 800
            canvas_h = 800
        
        # Fit image
        img_w, img_h = self.current_img.size
        self.scale = min(canvas_w / img_w, canvas_h / img_h)
        
        new_w = max(1, int(img_w * self.scale))
        new_h = max(1, int(img_h * self.scale))
        
        self.img_offset_x = (canvas_w - new_w) // 2
        self.img_offset_y = (canvas_h - new_h) // 2
        
        self.display_img = self.current_img.resize((new_w, new_h), Image.LANCZOS)
        
        self.status_var.set('Click and drag on the image to draw a box around the logo')
        self._redraw_canvas()
    
    def _redraw_canvas(self):
        self.canvas.delete('all')
        
        if self.display_img is None:
            return
        
        # Base image
        self.tk_img = ImageTk.PhotoImage(self.display_img)
        self.canvas.create_image(self.img_offset_x, self.img_offset_y,
                                 anchor='nw', image=self.tk_img)
        
        # Box overlay
        if self.box_start and self.box_end:
            x1 = min(self.box_start[0], self.box_end[0])
            y1 = min(self.box_start[1], self.box_end[1])
            x2 = max(self.box_start[0], self.box_end[0])
            y2 = max(self.box_start[1], self.box_end[1])
            
            # Fill
            self.canvas.create_rectangle(x1, y1, x2, y2,
                                         outline='', fill='lime', stipple='gray25')
            # Border
            self.canvas.create_rectangle(x1, y1, x2, y2,
                                         outline='lime', width=3, fill='')
            # Label
            self.canvas.create_text(x1 + 5, max(y1 - 14, 2),
                                    text='LOGO', fill='lime',
                                    font=('Consolas', 12, 'bold'), anchor='nw')
    
    def _canvas_to_image_coords(self, cx, cy):
        ix = (cx - self.img_offset_x) / self.scale
        iy = (cy - self.img_offset_y) / self.scale
        return ix, iy
    
    def _save_and_next(self):
        if self.box_start is None or self.box_end is None:
            self.status_var.set('⚠️  No box drawn! Click and drag first.')
            return
        
        x1_img, y1_img = self._canvas_to_image_coords(*self.box_start)
        x2_img, y2_img = self._canvas_to_image_coords(*self.box_end)
        x1_img, x2_img = min(x1_img, x2_img), max(x1_img, x2_img)
        y1_img, y2_img = min(y1_img, y2_img), max(y1_img, y2_img)
        
        img_w, img_h = self.current_img.size
        x_center = max(0, min(1, ((x1_img + x2_img) / 2) / img_w))
        y_center = max(0, min(1, ((y1_img + y2_img) / 2) / img_h))
        width    = max(0, min(1, (x2_img - x1_img) / img_w))
        height   = max(0, min(1, (y2_img - y1_img) / img_h))
        
        img_file = self.image_files[self.current_idx]
        label_file = os.path.splitext(img_file)[0] + '.txt'
        label_path = os.path.join(self.label_dir, label_file)
        with open(label_path, 'w') as f:
            f.write(f"0 {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")
        
        total_annotations = self._count_annotated()
        print(f"✓ [{total_annotations}] Saved: {label_file}")
        
        self.current_idx += 1
        self._load_image()
    
    def _skip(self):
        print(f"⏭️  Skipped: {self.image_files[self.current_idx]}")
        self.current_idx += 1
        self._load_image()
    
    def _previous(self):
        if self.current_idx > 0:
            self.current_idx -= 1
            self._load_image()
        else:
            self.status_var.set('⚠️  Already at first image')


# ============================================================
# LAUNCH - Skip already annotated images
# ============================================================

print("Opening annotation window...")
print("  Mode: SKIP ANNOTATED (only showing unannotated images)")
print("  S = Save & Next")
print("  N = Skip")
print("  P = Previous\n")

app = AnnotationApp(
    WORKSPACE_IMG, 
    WORKSPACE_LBL,
    skip_annotated=True  # Set to False to see all images
)
# Out:
# Opening annotation window...
#   Mode: SKIP ANNOTATED (only showing unannotated images)
#   S = Save & Next
#   N = Skip
#   P = Previous
#
# ✓ Loaded 128 UNANNOTATED images
#   (Skipping 3001 already annotated)
# ✓ [3002] Saved: altima_ac101lkqttn0225p1163626.txt
# ✓ [3003] Saved: altima_ne553l8stth2387msjr3342.txt
# ✓ [3004] Saved: ami_mg90720j05hongkong.txt
# ✓ [3005] Saved: ami_mg9073s.txt
# ✓ [3006] Saved: ami_mg90946lxz1n0839.txt
# ✓ [3007] Saved: ami_mg9097blxz1n0839.txt
# ✓ [3008] Saved: ami_mg90xx6lxz1n0839.txt
# ✓ [3009] Saved: appotech_b6thm0101611516arz.txt
# ✓ [3010] Saved: appotech_cw6630e1429050asth42200.txt
# ✓ [3011] Saved: appotech_cw66339e15200501asth5090161.txt
# ✓ [3012] Saved: appotech_cw6639e14290501asth422005.txt
# ✓ [3013] Saved: appotech_cw6639e14380501asth4260021.txt
# ✓ [3014] Saved: appotech_ea73463611745nrz.txt
# ✓ [3015] Saved: atheros_8131mal1ed268502c1135china.txt
# ✓ [3016] Saved: atheros_8161al3ad2r0794d1209tw.txt
# ✓ [3017] Saved: atheros_ar2413a001b41723c0607china.txt
# ✓ [3018] Saved: atheros_ar5312a00.txt
# ✓ [3019] Saved: atheros_ar6012bg1ab6765404b1012taiwan.txt
# ✓ [3020] Saved: atheros_ar7242ah1ah152321c1129taiwan.txt
# ✓ [3021] Saved: atheros_ar8012bg1ab75317b1025taiwan.txt
# ✓ [3022] Saved: atheros_ar8012bg1aba7252a41b1015taiwan.txt
# ✓ [3023] Saved: atheros_ar8033al1asq4p85d1309china.txt
# ✓ [3024] Saved: atheros_ar8131al1ed06834c41039china.txt
# ✓ [3025] Saved: atheros_ar8236al1asfcf9831016taiwan.txt
# ✓ [3026] Saved: atheros_ar8236al1asfgr6815517taiwan.txt
# ✓ [3027] Saved: atheros_ar9170al1an2n56001b1031taiwan.txt
# ✓ [3028] Saved: atheros_ar9285al1ad3s087b1247taiwan.txt
# ✓ [3029] Saved: atheros_ar9310.txt
# ✓ [3030] Saved: atheros_ar9331al1apbh097002c1126korea.txt
# ✓ [3031] Saved: atheros_ar9331al3apfu62440461203taiwan.txt
# ✓ [3032] Saved: atheros_ar9341al1apfs939001c1218korea.txt
# ✓ [3033] Saved: atheros_ar9341al1apfy379023c1221korea.txt
# ✓ [3034] Saved: atheros_ar9341al1appu608002b1317taiwan.txt
# ✓ [3035] Saved: atheros_ar9342bl1apfs972003c1442korea.txt
# ✓ [3036] Saved: atheros_int1200a0ghnc3950f01212taiwan.txt
# ✓ [3037] Saved: atheros_int550a3gtr00200d1212taiwan.txt
# ✓ [3038] Saved: atheros_wan342acekep3flb1ketaiwan.txt
# ✓ [3039] Saved: bt_bt101kc305169243a.txt
# ✓ [3040] Saved: bt_bt121kpj80b59570129833.txt
# ✓ [3041] Saved: bt_bt252kpj20digimizer4838614.txt
# ✓ [3042] Saved: bt_bt476kpj507259115f.txt
# ✓ [3043] Saved: bt_bt477kpj508549116ps047702.txt
# ✓ [3044] Saved: bt_bt653k9j462169313c.txt
# ✓ [3045] Saved: espr_esp32-dowdq6042020ub00ppvu13.txt
# ✓ [3046] Saved: espr_esp32c3.txt
# ✓ [3047] Saved: espr_esp32c3312021fn4dz82021jd00pba817.txt
# ✓ [3048] Saved: espr_esp32d2wd272017tubipp5198.txt
# ✓ [3049] Saved: espr_esp32d2wd402016llllll.txt
# ✓ [3050] Saved: espr_esp32dowd.txt
# ✓ [3051] Saved: espr_esp32dowdg6122017pcka36.txt
# ✓ [3052] Saved: espr_esp32dowdq6122017pcka36.txt
# ✓ [3053] Saved: espr_esp32dowdq6162018tubophpuo9.txt
# ✓ [3054] Saved: espr_esp32dowdq6502016p6w255.txt
# ✓ [3055] Saved: espr_esp32dowdv3042020u300prhx02.txt
# ✓ [3056] Saved: espr_esp32dowdv3362020ue00pv0t49.txt
# ✓ [3057] Saved: espr_esp32dowdv3ue00prhx02.txt
# ✓ [3058] Saved: espr_esp32picod4282017tjagap0p95.txt
# ✓ [3059] Saved: espr_esp32picov3.txt
# ✓ [3060] Saved: espr_esp32s2322019u00cn6v782.txt
# ✓ [3061] Saved: espr_esp32s3082022fb00pwt788.txt
# ✓ [3062] Saved: espr_esp32s3302022r2mnp632000ub00pvf495.txt
# ✓ [3063] Saved: espr_esp32sowd262018tub0pkau99.txt
# ✓ [3064] Saved: espr_esp32sowd472016p6w255.txt
# ✓ [3065] Saved: espr_esp8255ex222016pachoo.txt
# ✓ [3066] Saved: espr_esp8266ex292014povv01.txt
# ✓ [3067] Saved: espr_esp8285052016p46g10.txt
# ✓ [3068] Saved: exar_16c2852cjbc9938.txt
# ✓ [3069] Saved: exar_16c450cj9037.txt
# ✓ [3070] Saved: exar_2402cj8848.txt
# ✓ [3071] Saved: exar_2902cj9221.txt
# ✓ [3072] Saved: exar_82c684cj44dc0107.txt
# ✓ [3073] Saved: exar_82c684cj9520.txt
# ✓ [3074] Saved: exar_82c684cj9609.txt
# ✓ [3075] Saved: exar_88c681cjdc0024.txt
# ✓ [3076] Saved: exar_88c681cje2f0515.txt
# ✓ [3077] Saved: exar_st16c550cjbc0013.txt
# ✓ [3078] Saved: exar_st16c554dcqd2f0611.txt
# ✓ [3079] Saved: free_5c667623mm368n78sctme2335a.txt
# ✓ [3080] Saved: free_mc10xs3535hfkctny1728g.txt
# ✓ [3081] Saved: free_mc33984.txt
# ✓ [3082] Saved: free_mc33984bpnadual4ctaq1546.txt
# ✓ [3083] Saved: free_mc33984bpnadual4ctar1119b.txt
# ✓ [3084] Saved: free_mc33984bpnadual4ctx742260.txt
# ✓ [3085] Saved: free_mc33984bpnadual4ctzs1115a.txt
# ✓ [3086] Saved: free_mc33984bpnadual4ctzx11150.txt
# ✓ [3087] Saved: free_mc33984bpnadualctzs1115a.txt
# ✓ [3088] Saved: free_mc68hc000ei16.txt
# ✓ [3089] Saved: free_mk20dx256vl0105n22doctant64qj.txt
# ✓ [3090] Saved: genesys_gl3510os1ad05y52512d1tk69.txt
# ✓ [3091] Saved: genesys_gl35200v1bb02y10207n4y13300.txt
# ✓ [3092] Saved: genesys_gl35200v4da0172292on2wh8000.txt
# ✓ [3093] Saved: genesys_gl35200v4da01y22935no7w2100.txt
# ✓ [3094] Saved: genesys_gl3520dv1bb02y10207n4y13300.txt
# ✓ [3095] Saved: genesys_gl3520os3cf04y21429gne0701.txt
# ✓ [3096] Saved: genesys_gl3520ov4da0172214on4sgb300.txt
# ✓ [3097] Saved: microtune_mt2060505h50a067j2808a4.txt
# ✓ [3098] Saved: mosys_mdrammd908sj5100a04720adb9639.txt
# ✓ [3099] Saved: mosys_vd1amyu9c1aj51jr.txt
# ✓ [3100] Saved: neofi_150471155h1541s.txt
# ✓ [3101] Saved: netlogic_ac1763700m60ad6724saf30.txt
# ✓ [3102] Saved: oasis_fos81042440220aw714mlttegfcbp.txt
# ✓ [3103] Saved: oasis_fos81042440220c5710mlttegfcbp.txt
# ✓ [3104] Saved: oasis_fos81042440220cs710mlttegfcbp.txt
# ✓ [3105] Saved: oasis_fos81042440220dm707mlttegfcbp.txt
# ✓ [3106] Saved: oasis_fos81042440220el619mlttegfcbp.txt
# ✓ [3107] Saved: oasis_fos81042440220h8708mlttegfcd7.txt
# ✓ [3108] Saved: oasis_fos81042440220m8711mlttegfcbp.txt
# ✓ [3109] Saved: oasis_fos81042440220md818mlttegecbp.txt
# ✓ [3110] Saved: oasis_fos81042440220pj806mlttegfcbp.txt
# ✓ [3111] Saved: oasis_fos81042440p226d0406mlttegfcbpb06.txt
# ✓ [3112] Saved: oasis_fos81042440p22aj0440mlttegfcbp.txt
# ✓ [3113] Saved: oasis_os81042440220p9727mlttegfcbp.txt
# ✓ [3114] Saved: oasis_os81042440220qk434mlttegfcbp.txt
# ✓ [3115] Saved: oasis_os8104aa092101b0941t941256d.txt
# ✓ [3116] Saved: oasis_os81050ah429e1a1252t148998a.txt
# ✓ [3117] Saved: oasis_os8105dah429e1a1252t14b998a.txt
# ✓ [3118] Saved: parallax_p8x32aq44121bc25680.txt
# ✓ [3119] Saved: signetics_scn68000c8a68kkb55479101ke.txt
# ✓ [3120] Saved: sss_6691h1m6cj4803720b1046.txt
# ✓ [3121] Saved: sss_6695h2uscnru002100d1537.txt
# ✓ [3122] Saved: sss_6697h1u6cjak01510a1201.txt
# ✓ [3123] Saved: sss_6698h1uschpjto00081237.txt
# ✓ [3124] Saved: sss_hcf4053bf88427.txt
# ✓ [3125] Saved: uniden_uc1489al4818a70h4l1japan.txt
# ✓ [3126] Saved: vitalic_v63c330jo2.txt
# ✓ [3127] Saved: vlsi_807zx555q28380001tcc1014atandy1987koreaa.txt
# ✓ [3128] Saved: vlsi_9351as456432vm06578bmyk78tmykotronx.txt
# ✓ [3129] Saved: vlsi_solutionvs1010d931867020083.txt
