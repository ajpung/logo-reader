# %%
# ============================================================
# STEP 1: SYNC NEW IMAGES TO WORKSPACE
# ============================================================

import os
import shutil

COMPONENTS_DIR = './components/'
WORKSPACE_IMG  = './annotation_workspace/images/train'
WORKSPACE_LBL  = './annotation_workspace/labels/train'

os.makedirs(WORKSPACE_IMG, exist_ok=True)
os.makedirs(WORKSPACE_LBL, exist_ok=True)

# Get existing images in workspace
existing_images = set(os.listdir(WORKSPACE_IMG))

# Copy only NEW images
new_count = 0
for f in os.listdir(COMPONENTS_DIR):
    if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
        if f not in existing_images:
            shutil.copy(os.path.join(COMPONENTS_DIR, f), WORKSPACE_IMG)
            new_count += 1

img_count = len([f for f in os.listdir(WORKSPACE_IMG) if f.lower().endswith(('.png','.jpg','.jpeg','.bmp'))])
lbl_count = len([f for f in os.listdir(WORKSPACE_LBL) if f.endswith('.txt')])

print(f"✓ Copied {new_count} new images to workspace")
print(f"✓ Total images:      {img_count}")
print(f"✓ Total annotations: {lbl_count}")
print(f"✓ Remaining to annotate: {img_count - lbl_count}")
# Out:
# ✓ Copied 0 new images to workspace
# ✓ Total images:      2899
# ✓ Total annotations: 2575
# ✓ Remaining to annotate: 324

# %%
# ============================================================
# STEP 2: Enhanced Annotation Tool - Skip Annotated Images
# ============================================================

import tkinter as tk
from PIL import Image, ImageTk
import os

class AnnotationApp:
    def __init__(self, image_dir, label_dir, skip_annotated=True):
        self.image_dir = image_dir
        self.label_dir = label_dir
        self.skip_annotated = skip_annotated
        os.makedirs(label_dir, exist_ok=True)
        
        # Get ALL images
        all_images = sorted([
            f for f in os.listdir(image_dir)
            if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))
        ])
        
        if skip_annotated:
            # ONLY load unannotated images
            self.image_files = []
            for f in all_images:
                label_file = os.path.splitext(f)[0] + '.txt'
                if not os.path.exists(os.path.join(label_dir, label_file)):
                    self.image_files.append(f)
            
            print(f"✓ Loaded {len(self.image_files)} UNANNOTATED images")
            print(f"  (Skipping {len(all_images) - len(self.image_files)} already annotated)")
        else:
            # Load all images, resume from first unannotated
            self.image_files = all_images
            print(f"✓ Loaded {len(self.image_files)} total images")
        
        self.current_idx = 0  # Start at first unannotated
        
        self.box_start = None
        self.box_end = None
        self.dragging = False
        
        self.current_img = None
        self.display_img = None
        self.img_offset_x = 0
        self.img_offset_y = 0
        self.scale = 1.0
        
        self._build_ui()
        self.root.after(100, self._load_image)
        self.root.mainloop()
    
    def _count_annotated(self):
        """Count total annotations in label directory"""
        return len([f for f in os.listdir(self.label_dir) if f.endswith('.txt')])
    
    def _build_ui(self):
        self.root = tk.Tk()
        self.root.title('Logo Annotation Tool')
        self.root.configure(bg='#1e1e1e')
        
        screen_w = self.root.winfo_screenwidth()
        screen_h = self.root.winfo_screenheight()
        win_w = min(900, screen_w - 100)
        win_h = min(950, screen_h - 50)
        self.root.geometry(f'{win_w}x{win_h}')
        self.root.resizable(True, True)
        
        # --- Progress label ---
        self.progress_var = tk.StringVar(value='Loading...')
        tk.Label(
            self.root, textvariable=self.progress_var,
            bg='#1e1e1e', fg='white', font=('Consolas', 11, 'bold')
        ).pack(side='top', pady=(8, 2))
        
        # --- Canvas ---
        canvas_frame = tk.Frame(self.root, bg='#1e1e1e')
        canvas_frame.pack(side='top', fill='both', expand=True, padx=10)
        
        self.canvas = tk.Canvas(canvas_frame, bg='#111111', highlightthickness=0)
        self.canvas.pack(fill='both', expand=True)
        
        self.canvas.bind('<ButtonPress-1>',   self._on_mouse_down)
        self.canvas.bind('<B1-Motion>',       self._on_mouse_drag)
        self.canvas.bind('<ButtonRelease-1>', self._on_mouse_up)
        
        # Keyboard
        self.root.bind('<s>', lambda e: self._save_and_next())
        self.root.bind('<S>', lambda e: self._save_and_next())
        self.root.bind('<n>', lambda e: self._skip())
        self.root.bind('<N>', lambda e: self._skip())
        self.root.bind('<p>', lambda e: self._previous())
        self.root.bind('<P>', lambda e: self._previous())
        
        # --- Buttons ---
        btn_frame = tk.Frame(self.root, bg='#1e1e1e')
        btn_frame.pack(side='bottom', pady=10)
        
        btn_kw = {'font': ('Consolas', 12, 'bold'), 'width': 16,
                  'relief': 'flat', 'cursor': 'hand2', 'bd': 0}
        
        tk.Button(btn_frame, text='✓  Save & Next  [S]',
                  bg='#2ecc71', fg='white', activebackground='#27ae60', activeforeground='white',
                  command=self._save_and_next, **btn_kw
        ).pack(side='left', padx=8)
        
        tk.Button(btn_frame, text='⏭  Skip  [N]',
                  bg='#e67e22', fg='white', activebackground='#d35400', activeforeground='white',
                  command=self._skip, **btn_kw
        ).pack(side='left', padx=8)
        
        tk.Button(btn_frame, text='◀  Previous  [P]',
                  bg='#3498db', fg='white', activebackground='#2980b9', activeforeground='white',
                  command=self._previous, **btn_kw
        ).pack(side='left', padx=8)
        
        # --- Status bar ---
        self.status_var = tk.StringVar(value='Loading...')
        tk.Label(
            self.root, textvariable=self.status_var,
            bg='#2c2c2c', fg='#aaaaaa', font=('Consolas', 9)
        ).pack(side='bottom', fill='x')
    
    def _on_mouse_down(self, event):
        self.box_start = (event.x, event.y)
        self.box_end = None
        self.dragging = True
        self._redraw_canvas()
    
    def _on_mouse_drag(self, event):
        if self.dragging:
            self.box_end = (event.x, event.y)
            self._redraw_canvas()
    
    def _on_mouse_up(self, event):
        self.dragging = False
        if self.box_start and self.box_end:
            if abs(self.box_end[0] - self.box_start[0]) < 5 or \
               abs(self.box_end[1] - self.box_start[1]) < 5:
                self.box_start = None
                self.box_end = None
                self._redraw_canvas()
                return
            self.status_var.set('Box drawn!  Press S or click "Save & Next"')
        self._redraw_canvas()
    
    def _load_image(self):
        if self.current_idx >= len(self.image_files):
            self.progress_var.set('🎉  ALL DONE!')
            total_annotations = self._count_annotated()
            self.status_var.set(f'Finished! Total annotations: {total_annotations}')
            self.canvas.delete('all')
            return
        
        img_file = self.image_files[self.current_idx]
        self.current_img = Image.open(os.path.join(self.image_dir, img_file)).convert('RGB')
        
        # Progress text
        total_annotations = self._count_annotated()
        remaining = len(self.image_files) - self.current_idx
        self.progress_var.set(
            f'[{self.current_idx+1}/{len(self.image_files)}]  {img_file}  |  '
            f'Total annotated: {total_annotations} | Remaining: {remaining}'
        )
        
        # Reset box
        self.box_start = None
        self.box_end = None
        
        # Get actual canvas size
        self.root.update_idletasks()
        canvas_w = self.canvas.winfo_width()
        canvas_h = self.canvas.winfo_height()
        
        if canvas_w <= 1 or canvas_h <= 1:
            canvas_w = 800
            canvas_h = 800
        
        # Fit image
        img_w, img_h = self.current_img.size
        self.scale = min(canvas_w / img_w, canvas_h / img_h)
        
        new_w = max(1, int(img_w * self.scale))
        new_h = max(1, int(img_h * self.scale))
        
        self.img_offset_x = (canvas_w - new_w) // 2
        self.img_offset_y = (canvas_h - new_h) // 2
        
        self.display_img = self.current_img.resize((new_w, new_h), Image.LANCZOS)
        
        self.status_var.set('Click and drag on the image to draw a box around the logo')
        self._redraw_canvas()
    
    def _redraw_canvas(self):
        self.canvas.delete('all')
        
        if self.display_img is None:
            return
        
        # Base image
        self.tk_img = ImageTk.PhotoImage(self.display_img)
        self.canvas.create_image(self.img_offset_x, self.img_offset_y,
                                 anchor='nw', image=self.tk_img)
        
        # Box overlay
        if self.box_start and self.box_end:
            x1 = min(self.box_start[0], self.box_end[0])
            y1 = min(self.box_start[1], self.box_end[1])
            x2 = max(self.box_start[0], self.box_end[0])
            y2 = max(self.box_start[1], self.box_end[1])
            
            # Fill
            self.canvas.create_rectangle(x1, y1, x2, y2,
                                         outline='', fill='lime', stipple='gray25')
            # Border
            self.canvas.create_rectangle(x1, y1, x2, y2,
                                         outline='lime', width=3, fill='')
            # Label
            self.canvas.create_text(x1 + 5, max(y1 - 14, 2),
                                    text='LOGO', fill='lime',
                                    font=('Consolas', 12, 'bold'), anchor='nw')
    
    def _canvas_to_image_coords(self, cx, cy):
        ix = (cx - self.img_offset_x) / self.scale
        iy = (cy - self.img_offset_y) / self.scale
        return ix, iy
    
    def _save_and_next(self):
        if self.box_start is None or self.box_end is None:
            self.status_var.set('⚠️  No box drawn! Click and drag first.')
            return
        
        x1_img, y1_img = self._canvas_to_image_coords(*self.box_start)
        x2_img, y2_img = self._canvas_to_image_coords(*self.box_end)
        x1_img, x2_img = min(x1_img, x2_img), max(x1_img, x2_img)
        y1_img, y2_img = min(y1_img, y2_img), max(y1_img, y2_img)
        
        img_w, img_h = self.current_img.size
        x_center = max(0, min(1, ((x1_img + x2_img) / 2) / img_w))
        y_center = max(0, min(1, ((y1_img + y2_img) / 2) / img_h))
        width    = max(0, min(1, (x2_img - x1_img) / img_w))
        height   = max(0, min(1, (y2_img - y1_img) / img_h))
        
        img_file = self.image_files[self.current_idx]
        label_file = os.path.splitext(img_file)[0] + '.txt'
        label_path = os.path.join(self.label_dir, label_file)
        with open(label_path, 'w') as f:
            f.write(f"0 {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")
        
        total_annotations = self._count_annotated()
        print(f"✓ [{total_annotations}] Saved: {label_file}")
        
        self.current_idx += 1
        self._load_image()
    
    def _skip(self):
        print(f"⏭️  Skipped: {self.image_files[self.current_idx]}")
        self.current_idx += 1
        self._load_image()
    
    def _previous(self):
        if self.current_idx > 0:
            self.current_idx -= 1
            self._load_image()
        else:
            self.status_var.set('⚠️  Already at first image')


# ============================================================
# LAUNCH - Skip already annotated images
# ============================================================

print("Opening annotation window...")
print("  Mode: SKIP ANNOTATED (only showing unannotated images)")
print("  S = Save & Next")
print("  N = Skip")
print("  P = Previous\n")

app = AnnotationApp(
    WORKSPACE_IMG, 
    WORKSPACE_LBL,
    skip_annotated=True  # Set to False to see all images
)
# Out:
# Opening annotation window...
#   Mode: SKIP ANNOTATED (only showing unannotated images)
#   S = Save & Next
#   N = Skip
#   P = Previous
#
# ✓ Loaded 324 UNANNOTATED images
#   (Skipping 2575 already annotated)
# ✓ [2576] Saved: 3dfx_3550004520f21448106001520005taiwan1301.txt
# ✓ [2577] Saved: 3dfx_3550026220f251301as003120005taiwan1z01.txt
# ✓ [2578] Saved: 3dfx_3550026220f277721as003120005taiwan1z01.txt
# ✓ [2579] Saved: 3dfx_3550026320f318332sp004020005taiwan1401.txt
# ✓ [2580] Saved: 3dfx_355002e220f251191as003120005taiwan1z01.txt
# ✓ [2581] Saved: 3dfx_3550826220f267201sp082820305taiwan1501.txt
# ✓ [2582] Saved: 3dfx_500000102ba25411fbi962020001usapan.txt
# ✓ [2583] Saved: 3dfx_500000201ba57951imu962320001usapan.txt
# ✓ [2584] Saved: 3dfx_500000303b800961fbi964020001taiwan1001.txt
# ✓ [2585] Saved: 3dfx_500000303bc75791fbi973220001taiwan1001.txt
# ✓ [2586] Saved: 3dfx_500000303bf16441fbi974720001taiwan1001.txt
# ✓ [2587] Saved: 3dfx_500000303bf31711fbi975020001taiwan1001.txt
# ✓ [2588] Saved: 3dfx_500000303bf32711fbi975220001taiwan1001.txt
# ✓ [2589] Saved: 3dfx_500000303f006411fbi981620005taiwan1001.txt
# ✓ [2590] Saved: 3dfx_500000303f8052911fbi980420005taiwan1001.txt
# ✓ [2591] Saved: 3dfx_500000402bc72321tmu973320001taiwan1001.txt
# ✓ [2592] Saved: 3dfx_500000402bc72321tmutaiwan1001.txt
# ✓ [2593] Saved: 3dfx_500000402bf26871tmu974820001taiwan1001.txt
# ✓ [2594] Saved: 3dfx_500000402bf32281tmu975120001taiwan1001.txt
# ✓ [2595] Saved: 3dfx_500000402f0037911tmu980920005taiwan1001.txt
# ✓ [2596] Saved: 3dfx_500000402f0064211tmu981620005taiwan1001.txt
# ✓ [2597] Saved: 3dfx_500000402f8025011tmu975120005taiwan1001.txt
# ✓ [2598] Saved: 3dfx_500000402f8036411tmu975120005taiwan1001.txt
# ✓ [2599] Saved: 3dfx_500000402f8050211tmu9800220005taiwan1001.txt
# ✓ [2600] Saved: 3dfx_500000402f8050211tmu980220005taiwan1001.txt
# ✓ [2601] Saved: 3dfx_500000901d18646ck981320004taiwan1001.txt
# ✓ [2602] Saved: 3dfx_500000901d19969500ck981820004taiwan1001.txt
# ✓ [2603] Saved: 3dfx_50000100102104600be965020004taiwan1001.txt
# ✓ [2604] Saved: 3dfx_500001001d1738100be981020004taiwan1001.txt
# ✓ [2605] Saved: 3dfx_500001001d1761500be981120004taiwan1001.txt
# ✓ [2606] Saved: 3dfx_500001001d1873700be381220004taiwan1001.txt
# ✓ [2607] Saved: 3dfx_500001001d1873700be981220004taiwan1001.txt
# ✓ [2608] Saved: 3dfx_500001001d1900100be981620004taiwan1001.txt
# ✓ [2609] Saved: 3dfx_500001001d2104600be985020004taiwan1001.txt
# ✓ [2610] Saved: 3dfx_500001001d2110200be983720004taiwan1001.txt
# ✓ [2611] Saved: 3dfx_500001001f0093711be990920005taiwan1001.txt
# ✓ [2612] Saved: 3dfx_5000010d2150300be990720004taiwan1001.txt
# ✓ [2613] Saved: 3dfx_500001304f104791ban997720005taiwan3001.txt
# ✓ [2614] Saved: 3dfx_500001304f104801ban993420005taiwan3001.txt
# ✓ [2615] Saved: 3dfx_560008501g1984800ck990320004taiwan1001.txt
# ✓ [2616] Saved: 3dfx_voodoo2outin.txt
# ✓ [2617] Saved: 3dfx_voodoo2sliscanlineinterleave.txt
# ✓ [2618] Saved: 3dfx_vsa100igf6078320049taiwan28ca205aag.txt
# ✓ [2619] Saved: 3do_japan19933d000425001016sc800hf1039419eai.txt
# ✓ [2620] Saved: 3do_japan19933d0clio00425001016sc800hf1039419ea1.txt
# ✓ [2621] Saved: 3do_japan19933d0madam00426001016sc700hf1019419ea1.txt
# ✓ [2622] Saved: a3_chkc14b5aufp5552103.txt
# ✓ [2623] Saved: a3_cn1c14n5aeu03042510.txt
# ✓ [2624] Saved: a3_dcgb14d98e990481850.txt
# ✓ [2625] Saved: a3_jh3b14f3bugb6842115.txt
# ✓ [2626] Saved: acer_m3125j9030.txt
# ✓ [2627] Saved: acer_m3125nnr9112wg17379germany.txt
# ✓ [2628] Saved: acer_m5105a29205ts6a20518.txt
# ✓ [2629] Saved: acer_m5105a3e9209ts7a21241.txt
# ✓ [2630] Saved: acer_m5105a4e9248ts6t36937.txt
# ✓ [2631] Saved: acer_m5105a4e9441ts2aa8328e.txt
# ✓ [2632] Saved: action_a2305zd43xdab7a.txt
# ✓ [2633] Saved: action_v100fp1bmp32c.txt
# ✓ [2634] Saved: action_z35dtmp25c.txt
# ✓ [2635] Saved: afa_af9013sl20635hjqcl.txt
# ✓ [2636] Saved: alcor_au6254q41jblgrh6n006052f1110t7f1.txt
# ✓ [2637] Saved: alcor_au6371b51jelnph2155900742tc1.txt
# ✓ [2638] Saved: alcor_au6989anhl2n3r07511.txt
# ✓ [2639] Saved: alcor_au6989snblgtc1745t8a1l.txt
# ✓ [2640] Saved: alcor_au699bsnm84ghlgra2035301f1727196c2.txt
# ✓ [2641] Saved: alliance_semiconductorpromotionat251997b7f61b9739.txt
# ✓ [2642] Saved: amd_am29f200bt90ec9852fbah1997amd.txt
# ✓ [2643] Saved: anlogic_al3a10lg144c7015348060404.txt
# ✓ [2644] Saved: anlogic_ef3l90cg400b017356251524.txt
# ✓ [2645] Saved: anlogic_eg4s20bg25607356251524.txt
# ✓ [2646] Saved: anlogic_saldragon.txt
# ✓ [2647] Saved: appian_poach182c230129108cdacab.txt
# ✓ [2648] Saved: asl_cs5266a012592237.txt
# ✓ [2649] Saved: aspeed_ast1030p08y3800s3w2234tana1gp.txt
# ✓ [2650] Saved: aspeed_ast1035pnh6740ds1ew2220tana1gp.txt
# ✓ [2651] Saved: aspeed_ast1050g1hr221s11704tana1gp.txt
# ✓ [2652] Saved: aspeed_ast1060p69c2800s1ew2244tana2gp.txt
# ✓ [2653] Saved: aspeed_ast1060p6r12100s2e1422tanaogp.txt
# ✓ [2654] Saved: aspeed_ast1100gz49791910826tansp.txt
# ✓ [2655] Saved: aspeed_ast1220n4rw5200s12135tana1gp.txt
# ✓ [2656] Saved: aspeed_ast1520pnxt4500s21934tana2gp.txt
# ✓ [2657] Saved: aspeed_ast1520psg19700s12225tana2gp.txt
# ✓ [2658] Saved: aspeed_ast1530th9s9800s12217tana3gp.txt
# ✓ [2659] Saved: aspeed_ast1620gf0f301s12213a1gp.txt
# ✓ [2660] Saved: aspeed_ast1630du20090062228tana1gp.txt
# ✓ [2661] Saved: aspeed_ast2050g2k0491s10949tana3gp.txt
# ✓ [2662] Saved: aspeed_ast2050gvc4421s11523tana3gp.txt
# ✓ [2663] Saved: aspeed_ast2300g22n031s11715tana1gp.txt
# ✓ [2664] Saved: aspeed_ast2300ggx7561s11320tana1gp.txt
# ✓ [2665] Saved: aspeed_ast2400p1nb2400a11446tana1gp.txt
# ✓ [2666] Saved: aspeed_ast2400pa983100a11627tana1gp.txt
# ✓ [2667] Saved: aspeed_ast2400paub5700a11632tana1gp.txt
# ✓ [2668] Saved: aspeed_ast2400pomn3000a1e1427tana1gp.txt
# ✓ [2669] Saved: aspeed_ast2400pss21400a1e1341tana1gp.txt
# ✓ [2670] Saved: aspeed_ast2500a2gptaiwan1732123456789.txt
# ✓ [2671] Saved: aspeed_ast2500p4sb1900s11606tana1gp.txt
# ✓ [2672] Saved: aspeed_ast2500phsk0700s21820tana2gp.txt
# ✓ [2673] Saved: aspeed_ast2520p6w32200s731637tana2gp.txt
# ✓ [2674] Saved: aspeed_ast2600p6r12100s2e1422tanaogp.txt
# ✓ [2675] Saved: aspeed_ast2600pbr12100s2e1422tana0gp.txt
# ✓ [2676] Saved: aspeed_ast2600t01b0500s22152tana3gp.txt
# ✓ [2677] Saved: aspeed_ast2600thwh7800s22227tana3gp.txt
# ✓ [2678] Saved: aspeed_ast2620a3gpj9e543madeintaiwan.txt
# ✓ [2679] Saved: aspeed_ast2750p6am6500s12338tana0gp.txt
# ✓ [2680] Saved: aspeed_pilot4p01049401c16311qc002taiwan.txt
# ✓ [2681] Saved: atmel_atmega324paau0953.txt
# ✓ [2682] Saved: audiocodes_ac491cb980320aclggucb32a392w.txt
# ✓ [2683] Saved: audiocodes_ac494cbv494aclgdw9804c4p1118.txt
# ✓ [2684] Saved: cmedia_cm6206rkrskugg1amgzgs2113.txt
# ✓ [2685] Saved: conexant_2056114z990017020902cn.txt
# ✓ [2686] Saved: conexant_cx2058411zbf46052040947my.txt
# ✓ [2687] Saved: conexant_cx2058411zfn46146031106my.txt
# ✓ [2688] Saved: conexant_cx2058510z6coe3630520902my.txt
# ✓ [2689] Saved: conexant_cx2058711ze145198031024my.txt
# ✓ [2690] Saved: conexant_cx2058711ze145869051027my.txt
# ✓ [2691] Saved: conexant_cx2058711ze145889051027my.txt
# ✓ [2692] Saved: conexant_cx2058711zea148890111103tw.txt
# ✓ [2693] Saved: conexant_cx2058711zfcnn51172121112tw.txt
# ✓ [2694] Saved: conexant_cx2058711zfcnp04006121115tw.txt
# ✓ [2695] Saved: conexant_cx2064111zncq10087131221tw.txt
# ✓ [2696] Saved: conexant_cx2067121zaa612773131121tw.txt
# ✓ [2697] Saved: conexant_cx2067211zbf46053010947my.txt
# ✓ [2698] Saved: conexant_cx2067211ze602943081006my.txt
# ✓ [2699] Saved: conexant_cx2067211ze603415051005my.txt
# ✓ [2700] Saved: conexant_cx2070312z110540231128korea.txt
# ✓ [2701] Saved: conexant_cx2070921zcnp44092121205tw.txt
# ✓ [2702] Saved: conexant_cx2310211zn2k997041120sg.txt
# ✓ [2703] Saved: conexant_cx9216519zp87w05d021527twarm.txt
# ✓ [2704] Saved: conexant_cx97310110513taiwan0513gwuu.txt
# ✓ [2705] Saved: connor_nf2004rev1001740.txt
# ✓ [2706] Saved: cti_14030710000mhzosc5a2b02.txt
# ✓ [2707] Saved: cti_14040510000mhzosc5a2b02cetc.txt
# ✓ [2708] Saved: easii_ezid211es2eicl005832447a21.txt
# ✓ [2709] Saved: easii_ezid211eseicl001022234a09.txt
# ✓ [2710] Saved: ess_es9018sc10066svb603889leadfree.txt
# ✓ [2711] Saved: ess_es9038pro.txt
# ✓ [2712] Saved: etron_em614163a50vc03w81267.txt
# ✓ [2713] Saved: fe_3254f10d73db.txt
# ✓ [2714] Saved: fe_3289f1d05n29.txt
# ✓ [2715] Saved: fe_3293fn086ahe.txt
# ✓ [2716] Saved: fe_3294f1006932e.txt
# ✓ [2717] Saved: fe_3294f100717je.txt
# ✓ [2718] Saved: fe_3294f1d07941e.txt
# ✓ [2719] Saved: fe_3294f1d08805e.txt
# ✓ [2720] Saved: fe_3294f1d08805i.txt
# ✓ [2721] Saved: fe_3294f1dd7305.txt
# ✓ [2722] Saved: fe_3298f1n06017.txt
# ✓ [2723] Saved: fe_3298f1n07415.txt
# ✓ [2724] Saved: fe_3298f1n076cj.txt
# ✓ [2725] Saved: fe_3401f1n07939.txt
# ✓ [2726] Saved: fe_3401f1n07dfk.txt
# ✓ [2727] Saved: fe_3407f0n085fda.txt
# ✓ [2728] Saved: fe_3407f1n07046a.txt
# ✓ [2729] Saved: fe_3407f1n070cna.txt
# ✓ [2730] Saved: fe_3407f1n078a1a.txt
# ✓ [2731] Saved: fe_3407f1n078dja.txt
# ✓ [2732] Saved: fe_3407f1n079cca.txt
# ✓ [2733] Saved: fe_3407f1n07ddpa.txt
# ✓ [2734] Saved: fe_3407f1n083jsa.txt
# ✓ [2735] Saved: fe_3407f1n08608a.txt
# ✓ [2736] Saved: fe_3407f1n08609a.txt
# ✓ [2737] Saved: fe_3407f1n08807a.txt
# ✓ [2738] Saved: fe_3407f1n08899a.txt
# ✓ [2739] Saved: fe_3407f1n088a7a.txt
# ✓ [2740] Saved: fe_3407f1n08932a.txt
# ✓ [2741] Saved: fe_3407f1n08952a.txt
# ✓ [2742] Saved: fe_3407f1n08968a.txt
# ✓ [2743] Saved: fe_3407f1n815eha.txt
# ✓ [2744] Saved: fe_8407f1n08448a.txt
# ✓ [2745] Saved: fe_84g7f1n08448a.txt
# ✓ [2746] Saved: free_10061410893sc550108mfu33.txt
# ✓ [2747] Saved: free_sc900684aafm02fqda1112.txt
# ✓ [2748] Saved: free_sc900684aafm02fqgq1224e.txt
# ✓ [2749] Saved: free_sc900684abfm02fqak1333w.txt
# ✓ [2750] Saved: free_sc900714aeds1ctnz1729d.txt
# ✓ [2751] Saved: fresco_fl11001q0exkrmay0001723b01c.txt
# ✓ [2752] Saved: fsc_0516fs9721lp3myjco02.txt
# ✓ [2753] Saved: gaia_c0000173.txt
# ✓ [2754] Saved: gc_gc7721aqlp3fa675110.txt
# ✓ [2755] Saved: gc_gc7721aqp1fa675110.txt
# ✓ [2756] Saved: gc_gc7721aqp1pfa675110.txt
# ✓ [2757] Saved: hitachi_0e1hd64570f16japan.txt
# ✓ [2758] Saved: hitachi_0e455ha13627malaysia.txt
# ✓ [2759] Saved: hitachi_5d2hd44780a00.txt
# ✓ [2760] Saved: hitachi_h839475h1hd6433947fa05japan.txt
# ✓ [2761] Saved: hitachi_h8s2357hd9l26472357f24.txt
# ✓ [2762] Saved: hitachi_hd431099l45.txt
# ✓ [2763] Saved: hitachi_hd43191a031e15.txt
# ✓ [2764] Saved: hitachi_hd44352a017h1l3.txt
# ✓ [2765] Saved: hitachi_hd443537g33.txt
# ✓ [2766] Saved: hitachi_hd62111a017g13.txt
# ✓ [2767] Saved: hitachi_s6l5hd44780a00.txt
# ✓ [2768] Saved: iit_3c8733ah33aa1002eb3e5hc1cbnu9314iit1988.txt
# ✓ [2769] Saved: iit_3c8733ah33aa1002ed5c5hc0cccm9403iit1988.txt
# ✓ [2770] Saved: iit_3c8733ah33aa1002em4e5hc1cbrr.txt
# ✓ [2771] Saved: iit_3c8733ah33aa1002fc9e5hc1ccbk9348iit1988.txt
# ✓ [2772] Saved: iit_3c87401002fa2f5hc0ccit9437iit1988.txt
# ✓ [2773] Saved: iit_3c8740iit19881002ec5chc1cbfc9247.txt
# ✓ [2774] Saved: iit_3c8740iit19881002ed5c5hc1cble9302.txt
# ✓ [2775] Saved: iit_3c87sx26iit19901004eb3c3e1bbaian9225.txt
# ✓ [2776] Saved: iit_3c87sx401004fa2faec0ccnh9524iit1990.txt
# ✓ [2777] Saved: iit_4c87dlc251002fc9e5hc1ceadi9334iit1998.txt
# ✓ [2778] Saved: iit_4c87dlc33ah33aa1002ee5c5hc1cbmoa9309iit1990.txt
# ✓ [2779] Saved: iit_4c87dlc401002fa2f3ecoccka9504iit1990.txt
# ✓ [2780] Saved: iit_4c87dlc401002fa2f5hcoccgea9421iit1988.txt
# ✓ [2781] Saved: iit_4c87dlc401002fa2faec0ccg5942600iit1990.txt
# ✓ [2782] Saved: iit_4c87dlc401002fa2faec0ccgr9432iit1990.txt
# ✓ [2783] Saved: iit_4c87dlc401002fa2faec0cckm9510iit1990.txt
# ✓ [2784] Saved: iit_4c87dlc401002fbae5hc1ccfq9423iit1988.txt
# ✓ [2785] Saved: iit_4c87dlc401002fc9e5hc1cceq9407iit1988.txt
# ✓ [2786] Saved: iit_4c87dlc40153623511191002fa2f3ec0c.txt
# ✓ [2787] Saved: iit_4c87dlc40ae40aa1002ec6e5hc1cccf9352iit1989.txt
# ✓ [2788] Saved: iit_4c87dlc40ah40aa1002ee5c5hc1ccaf9341iit1988.txt
# ✓ [2789] Saved: iit_4c87dlc40ah40aa1002ee5hc1cc009405iit1988.txt
# ✓ [2790] Saved: iit_4c87dlc40ah40aa1002fc9e5hc1cbzm9337iit1988.txt
# ✓ [2791] Saved: iit_4c87dlc40ah40aa1002fc9e5hc1ccdo9406iit1988.txt
# ✓ [2792] Saved: iit_4c87dlc40ah40aa1002fc9e5hc1ceade9333iit1988.txt
# ✓ [2793] Saved: iit_4c87dlc40ah40aa1002fc9e5hc1ceadh9334iit1988.txt
# ✓ [2794] Saved: iit_x21202gc4g5hcoacmb9450iit1988.txt
# ✓ [2795] Saved: iit_xc87dlc331002faae5hc5ceaksa9410iit1988.txt
# ✓ [2796] Saved: iit_xc87slc33ae33aa1004em4eaec1cbom9313iit1990.txt
# ✓ [2797] Saved: iit_xc87slc33ae33aa1004fb9eaec1ceaen9323iit1990.txt
# ✓ [2798] Saved: issi_is61c641612te6048000pc9822.txt
# ✓ [2799] Saved: jl_ac1336h7t346b.txt
# ✓ [2800] Saved: jl_ac16450mb6201.txt
# ✓ [2801] Saved: jl_ac19ap1p8721a8.txt
# ✓ [2802] Saved: jl_ac19ap1z35221a8.txt
# ✓ [2803] Saved: jl_ac19ap1z36221a8.txt
# ✓ [2804] Saved: jl_ac20bp078325a8.txt
# ✓ [2805] Saved: jl_ac21bp0975721a8.txt
# ✓ [2806] Saved: jl_ac21bp0c91121ab.txt
# ✓ [2807] Saved: jl_ac23bp0665821a8.txt
# ✓ [2808] Saved: jl_ac23bp0f42721a8.txt
# ✓ [2809] Saved: jl_ac23bp0f6861a8.txt
# ✓ [2810] Saved: jl_ac6901.txt
# ✓ [2811] Saved: jmicron_jm203291046lgca4c372je001b.txt
# ✓ [2812] Saved: konami_0532519006w01.txt
# ✓ [2813] Saved: macrosi_ms9333n14ardfdhl09.txt
# ✓ [2814] Saved: mcmaster_japansla6430j2a72x8300ibmc6za209.txt
# ✓ [2815] Saved: mlogic_s905l3btbut3500a1cadn10417.txt
# ✓ [2816] Saved: mosys_mdrammd908sj5100.txt
# ✓ [2817] Saved: mvsi_ap8048acj164clr.txt
# ✓ [2818] Saved: orchid_nolabel.txt
# ✓ [2819] Saved: pmd_mc58420.txt
# ✓ [2820] Saved: pmlabs_esc0830.txt
# ✓ [2821] Saved: pmlabs_esc08302440chn.txt
# ✓ [2822] Saved: real3d_9649b849862vm21113c163a154636p1protophillippines.txt
# ✓ [2823] Saved: sc104034magr1l15yqqmv0906.txt
# ✓ [2824] Saved: scitel_u0813sc14434anf100vvgw38043.txt
# ✓ [2825] Saved: scitel_u0937sc14429cnf128vvt9019361.txt
# ✓ [2825] Saved: sc104034magr1l15yqqmv0906.txt
# ✓ [2825] Saved: scitel_u0813sc14434anf100vvgw38043.txt
# ✓ [2825] Saved: scitel_u0937sc14429cnf128vvt9019361.txt
# ✓ [2826] Saved: scitel_uu0715sc14470bnf128vvgp97461.txt
# ✓ [2827] Saved: scitel_uw0845sc14480a5mpso4vew0a93800p.txt
# ✓ [2828] Saved: scitel_uw1008sc14480a5ms21vew0m20200p.txt
# ✓ [2829] Saved: sie_cxd90042gg1704bhhtcttnr042002taiwan.txt
# ✓ [2830] Saved: sie_cxd90042gg1704bhhthcttnr042002taiwan.txt
# ✓ [2831] Saved: silabs_5d3502cne3llllllllllllle3yywwtwn.txt
# ✓ [2832] Saved: silicon_bg22.txt
# ✓ [2833] Saved: silicon_bgm220p.txt
# ✓ [2834] Saved: silicon_efr32bg27led0.txt
# ✓ [2835] Saved: silicon_efr32bg27reset.txt
# ✓ [2836] Saved: silicon_efr32bluetoothsoc.txt
# ✓ [2837] Saved: silicon_efr32fg.txt
# ✓ [2838] Saved: silicon_efr32mg21.txt
# ✓ [2839] Saved: silicon_efr32xg22eqwbc.txt
# ✓ [2840] Saved: silicon_efr32xg2724ghz4dbmdcdcbuckwlcsp.txt
# ✓ [2841] Saved: silicon_mgm111.txt
# ✓ [2842] Saved: silicon_mgm210l.txt
# ✓ [2843] Saved: silicon_mgm260p.txt
# ✓ [2844] Saved: silicon_mightygeckomgm13p.txt
# ✓ [2845] Saved: silicon_nolabel.txt
# ✓ [2846] Saved: silicon_si106x8x.txt
# ✓ [2847] Saved: silicon_wirelessstkenergyfriendlyradiostarterkit.txt
# ✓ [2848] Saved: silicon_xgm240p20dbm.txt
# ✓ [2849] Saved: silicon_xgm240s10dbm.txt
# ✓ [2850] Saved: silicon_xgm270sbuiltinantenna.txt
# ✓ [2851] Saved: silicon_xgm270smikrobusqwbc.txt
# ✓ [2852] Saved: sililcon_bg27.txt
# ✓ [2853] Saved: sililcon_efr32xg2724ghz4dbmdcdcbuckwlcsp.txt
# ✓ [2854] Saved: sino_sr79f198af1908044frnkpon.txt
# ✓ [2855] Saved: sirf_gsp2elp74500444dfqcbak6343china.txt
# ✓ [2856] Saved: sis_730ssis00pld0486l0106ka.txt
# ✓ [2857] Saved: sis_900sis98pjd24219923cra2.txt
# ✓ [2858] Saved: skyworks_7762131521203211847nx.txt
# ✓ [2859] Saved: skyworks_7763821497197111827mx.txt
# ✓ [2860] Saved: skyworks_779163144148p154.txt
# ✓ [2861] Saved: slie_cxd90042gg1704bhhthcttnr042002taiwan.txt
# ✓ [2862] Saved: sss_1629a5u6chyh5l001822.txt
# ✓ [2863] Saved: sss_1629a5u6chyhhl001822.txt
# ✓ [2864] Saved: sss_1629a5u6cu23gs012048.txt
# ✓ [2865] Saved: sss_6690u2m6chlyyp00150939.txt
# ✓ [2866] Saved: sss_6691h1m6cj4803830g1046.txt
# ✓ [2867] Saved: sss_6695h2u6cnru002100d1337.txt
# ✓ [2868] Saved: sss_6698h1uschpjt0000b1237.txt
# ✓ [2869] Saved: sss_s895h2u6cmsh20110001545.txt
# ✓ [2870] Saved: terminus_fe11sle30934b12410.txt
# ✓ [2871] Saved: terminus_fe11susb20hubmd39835b16509c.txt
# ✓ [2872] Saved: terminus_fe11usb20hubld31858a18269.txt
# ✓ [2873] Saved: terminus_fe11usb20hubld35153a18319.txt
# ✓ [2874] Saved: terminus_fe121ld3g030a1092.txt
# ✓ [2875] Saved: terminus_fe123ld3g030a1092.txt
# ✓ [2876] Saved: terminus_fe21usb20hubld3n664a7119.txt
# ✓ [2877] Saved: terminus_fe21usb20hubld3s983a7309.txt
# ✓ [2878] Saved: terminus_fe41lg3j978a6103.txt
# ✓ [2879] Saved: terminus_fe81ne36022a4330.txt
# ✓ [2880] Saved: texas_usroboticsd172a4pza92hhu8baf12w.txt
# ✓ [2881] Saved: trinamic_tmc2209lagermany.txt
# ✓ [2882] Saved: trinamic_tmc261es010539416germany.txt
# ✓ [2883] Saved: trinamic_tmc389la261081951.txt
# ✓ [2884] Saved: trinamic_tmc5160awagermany.txt
# ✓ [2885] Saved: trinamic_tmc603la4208germany.txt
# ✓ [2886] Saved: trinamic_tmc6148lagermany.txt
# ✓ [2887] Saved: trinamic_tmc6180lagermany.txt
# ✓ [2888] Saved: trinamic_tmc6200tagermany.txt
# ✓ [2889] Saved: trinamic_tmc6300lagermany.txt
# ✓ [2890] Saved: ulsi_advancedmathcoprocessorsxslc1990111019404ppa.txt
# ✓ [2891] Saved: vli_vl820q81636csd084241300.txt
# ✓ [2892] Saved: vlsi_vs1083a11515101210.txt
# ✓ [2893] Saved: vpd_bh1dsvc608000d00c.txt
# ✓ [2894] Saved: wch_ch91411042db34.txt
# ✓ [2895] Saved: winrise_hbs2268abc2258jt.txt
# ✓ [2896] Saved: wiseview_laxc021t1bq1sc379001010cec104100.txt
# ✓ [2897] Saved: wuxi_btj9201.txt
# ✓ [2898] Saved: xilinx_xc18v02tmvqg44btthd041adt.txt
# ✓ [2899] Saved: zarlink_zl103130607ewld.txt
