# %%
# ============================================================
# STEP 1: Verify workspace exists
# ============================================================

import os
import shutil

COMPONENTS_DIR = './components/'
WORKSPACE_IMG  = './annotation_workspace/images/train'
WORKSPACE_LBL  = './annotation_workspace/labels/train'

os.makedirs(WORKSPACE_IMG, exist_ok=True)
os.makedirs(WORKSPACE_LBL, exist_ok=True)

# Copy images if workspace is empty
if len(os.listdir(WORKSPACE_IMG)) == 0:
    print("Copying images to workspace...")
    for f in os.listdir(COMPONENTS_DIR):
        if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
            shutil.copy(os.path.join(COMPONENTS_DIR, f), WORKSPACE_IMG)

img_count = len([f for f in os.listdir(WORKSPACE_IMG) if f.lower().endswith(('.png','.jpg','.jpeg','.bmp'))])
lbl_count = len([f for f in os.listdir(WORKSPACE_LBL) if f.endswith('.txt')])

print(f"✓ Images:      {img_count}")
print(f"✓ Annotations: {lbl_count}")
print(f"✓ Remaining:   {img_count - lbl_count}")
# Out:
# ✓ Images:      2556
# ✓ Annotations: 2197
# ✓ Remaining:   359

# %%
# ============================================================
# STEP 2: Standalone Tkinter Annotation Tool - FIXED
# ============================================================

import tkinter as tk
from PIL import Image, ImageTk
import os

class AnnotationApp:
    def __init__(self, image_dir, label_dir):
        self.image_dir = image_dir
        self.label_dir = label_dir
        os.makedirs(label_dir, exist_ok=True)
        
        self.image_files = sorted([
            f for f in os.listdir(image_dir)
            if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))
        ])
        
        # Auto-resume
        self.current_idx = len(self.image_files)
        for i, f in enumerate(self.image_files):
            label_file = os.path.splitext(f)[0] + '.txt'
            if not os.path.exists(os.path.join(label_dir, label_file)):
                self.current_idx = i
                break
        
        self.box_start = None
        self.box_end = None
        self.dragging = False
        
        self.current_img = None
        self.display_img = None
        self.img_offset_x = 0
        self.img_offset_y = 0
        self.scale = 1.0
        
        self._build_ui()
        
        # FIXED: Wait for window to actually render, THEN load first image
        # root.after() schedules _load_image to run after the event loop starts
        self.root.after(100, self._load_image)
        
        self.root.mainloop()
    
    def _count_annotated(self):
        return sum(1 for f in self.image_files
                   if os.path.exists(os.path.join(self.label_dir,
                      os.path.splitext(f)[0] + '.txt')))
    
    def _build_ui(self):
        self.root = tk.Tk()
        self.root.title('Logo Annotation Tool')
        self.root.configure(bg='#1e1e1e')
        
        screen_w = self.root.winfo_screenwidth()
        screen_h = self.root.winfo_screenheight()
        win_w = min(900, screen_w - 100)
        win_h = min(950, screen_h - 50)
        self.root.geometry(f'{win_w}x{win_h}')
        self.root.resizable(True, True)
        
        # --- Progress label ---
        self.progress_var = tk.StringVar(value='Loading...')
        tk.Label(
            self.root, textvariable=self.progress_var,
            bg='#1e1e1e', fg='white', font=('Consolas', 11, 'bold')
        ).pack(side='top', pady=(8, 2))
        
        # --- Canvas ---
        canvas_frame = tk.Frame(self.root, bg='#1e1e1e')
        canvas_frame.pack(side='top', fill='both', expand=True, padx=10)
        
        self.canvas = tk.Canvas(canvas_frame, bg='#111111', highlightthickness=0)
        self.canvas.pack(fill='both', expand=True)
        
        self.canvas.bind('<ButtonPress-1>',   self._on_mouse_down)
        self.canvas.bind('<B1-Motion>',       self._on_mouse_drag)
        self.canvas.bind('<ButtonRelease-1>', self._on_mouse_up)
        
        # Keyboard
        self.root.bind('<s>', lambda e: self._save_and_next())
        self.root.bind('<S>', lambda e: self._save_and_next())
        self.root.bind('<n>', lambda e: self._skip())
        self.root.bind('<N>', lambda e: self._skip())
        self.root.bind('<p>', lambda e: self._previous())
        self.root.bind('<P>', lambda e: self._previous())
        
        # --- Buttons ---
        btn_frame = tk.Frame(self.root, bg='#1e1e1e')
        btn_frame.pack(side='bottom', pady=10)
        
        btn_kw = {'font': ('Consolas', 12, 'bold'), 'width': 16,
                  'relief': 'flat', 'cursor': 'hand2', 'bd': 0}
        
        tk.Button(btn_frame, text='✓  Save & Next  [S]',
                  bg='#2ecc71', fg='white', activebackground='#27ae60', activeforeground='white',
                  command=self._save_and_next, **btn_kw
        ).pack(side='left', padx=8)
        
        tk.Button(btn_frame, text='⏭  Skip  [N]',
                  bg='#e67e22', fg='white', activebackground='#d35400', activeforeground='white',
                  command=self._skip, **btn_kw
        ).pack(side='left', padx=8)
        
        tk.Button(btn_frame, text='◀  Previous  [P]',
                  bg='#3498db', fg='white', activebackground='#2980b9', activeforeground='white',
                  command=self._previous, **btn_kw
        ).pack(side='left', padx=8)
        
        # --- Status bar ---
        self.status_var = tk.StringVar(value='Loading...')
        tk.Label(
            self.root, textvariable=self.status_var,
            bg='#2c2c2c', fg='#aaaaaa', font=('Consolas', 9)
        ).pack(side='bottom', fill='x')
    
    # ----------------------------------------------------------
    # Mouse handlers
    # ----------------------------------------------------------
    
    def _on_mouse_down(self, event):
        self.box_start = (event.x, event.y)
        self.box_end = None
        self.dragging = True
        self._redraw_canvas()
    
    def _on_mouse_drag(self, event):
        if self.dragging:
            self.box_end = (event.x, event.y)
            self._redraw_canvas()
    
    def _on_mouse_up(self, event):
        self.dragging = False
        if self.box_start and self.box_end:
            if abs(self.box_end[0] - self.box_start[0]) < 5 or \
               abs(self.box_end[1] - self.box_start[1]) < 5:
                self.box_start = None
                self.box_end = None
                self._redraw_canvas()
                return
            self.status_var.set('Box drawn!  Press S or click "Save & Next"')
        self._redraw_canvas()
    
    # ----------------------------------------------------------
    # Image loading
    # ----------------------------------------------------------
    
    def _load_image(self):
        if self.current_idx >= len(self.image_files):
            self.progress_var.set('🎉  ALL DONE!')
            self.status_var.set(f'All {len(self.image_files)} images annotated.')
            self.canvas.delete('all')
            return
        
        img_file = self.image_files[self.current_idx]
        self.current_img = Image.open(os.path.join(self.image_dir, img_file)).convert('RGB')
        
        # Progress text
        done = self._count_annotated()
        total = len(self.image_files)
        self.progress_var.set(
            f'[{self.current_idx+1}/{total}]  {img_file}  |  {done}/{total} done ({done/total*100:.0f}%)'
        )
        
        # Reset box
        self.box_start = None
        self.box_end = None
        
        # Get actual canvas size (guaranteed valid here because of after())
        self.root.update_idletasks()
        canvas_w = self.canvas.winfo_width()
        canvas_h = self.canvas.winfo_height()
        
        # Safety check - fallback if still 0 for some reason
        if canvas_w <= 1 or canvas_h <= 1:
            canvas_w = 800
            canvas_h = 800
        
        # Fit image into canvas keeping aspect ratio
        img_w, img_h = self.current_img.size
        self.scale = min(canvas_w / img_w, canvas_h / img_h)
        
        new_w = max(1, int(img_w * self.scale))
        new_h = max(1, int(img_h * self.scale))
        
        self.img_offset_x = (canvas_w - new_w) // 2
        self.img_offset_y = (canvas_h - new_h) // 2
        
        self.display_img = self.current_img.resize((new_w, new_h), Image.LANCZOS)
        
        # Load existing annotation if present
        label_file = os.path.splitext(img_file)[0] + '.txt'
        label_path = os.path.join(self.label_dir, label_file)
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                parts = f.readline().strip().split()
                if len(parts) == 5:
                    _, xc, yc, w, h = map(float, parts)
                    x1 = int((xc - w/2) * img_w * self.scale + self.img_offset_x)
                    y1 = int((yc - h/2) * img_h * self.scale + self.img_offset_y)
                    x2 = int((xc + w/2) * img_w * self.scale + self.img_offset_x)
                    y2 = int((yc + h/2) * img_h * self.scale + self.img_offset_y)
                    self.box_start = (x1, y1)
                    self.box_end   = (x2, y2)
            self.status_var.set('Already annotated. Draw new box to overwrite, or press N to skip.')
        else:
            self.status_var.set('Click and drag on the image to draw a box around the logo')
        
        self._redraw_canvas()
    
    # ----------------------------------------------------------
    # Canvas drawing
    # ----------------------------------------------------------
    
    def _redraw_canvas(self):
        self.canvas.delete('all')
        
        if self.display_img is None:
            return
        
        # Base image
        self.tk_img = ImageTk.PhotoImage(self.display_img)
        self.canvas.create_image(self.img_offset_x, self.img_offset_y,
                                 anchor='nw', image=self.tk_img)
        
        # Box overlay
        if self.box_start and self.box_end:
            x1 = min(self.box_start[0], self.box_end[0])
            y1 = min(self.box_start[1], self.box_end[1])
            x2 = max(self.box_start[0], self.box_end[0])
            y2 = max(self.box_start[1], self.box_end[1])
            
            # Fill
            self.canvas.create_rectangle(x1, y1, x2, y2,
                                         outline='', fill='lime', stipple='gray25')
            # Border
            self.canvas.create_rectangle(x1, y1, x2, y2,
                                         outline='lime', width=3, fill='')
            # Label
            self.canvas.create_text(x1 + 5, max(y1 - 14, 2),
                                    text='LOGO', fill='lime',
                                    font=('Consolas', 12, 'bold'), anchor='nw')
    
    # ----------------------------------------------------------
    # Actions
    # ----------------------------------------------------------
    
    def _canvas_to_image_coords(self, cx, cy):
        ix = (cx - self.img_offset_x) / self.scale
        iy = (cy - self.img_offset_y) / self.scale
        return ix, iy
    
    def _save_and_next(self):
        if self.box_start is None or self.box_end is None:
            self.status_var.set('⚠️  No box drawn! Click and drag first.')
            return
        
        x1_img, y1_img = self._canvas_to_image_coords(*self.box_start)
        x2_img, y2_img = self._canvas_to_image_coords(*self.box_end)
        x1_img, x2_img = min(x1_img, x2_img), max(x1_img, x2_img)
        y1_img, y2_img = min(y1_img, y2_img), max(y1_img, y2_img)
        
        img_w, img_h = self.current_img.size
        x_center = max(0, min(1, ((x1_img + x2_img) / 2) / img_w))
        y_center = max(0, min(1, ((y1_img + y2_img) / 2) / img_h))
        width    = max(0, min(1, (x2_img - x1_img) / img_w))
        height   = max(0, min(1, (y2_img - y1_img) / img_h))
        
        img_file = self.image_files[self.current_idx]
        label_file = os.path.splitext(img_file)[0] + '.txt'
        label_path = os.path.join(self.label_dir, label_file)
        with open(label_path, 'w') as f:
            f.write(f"0 {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")
        
        print(f"✓ [{self._count_annotated()}/{len(self.image_files)}] Saved: {label_file}")
        
        self.current_idx += 1
        self._load_image()
    
    def _skip(self):
        print(f"⏭️  Skipped: {self.image_files[self.current_idx]}")
        self.current_idx += 1
        self._load_image()
    
    def _previous(self):
        if self.current_idx > 0:
            self.current_idx -= 1
            self._load_image()
        else:
            self.status_var.set('⚠️  Already at first image')


# ============================================================
# LAUNCH
# ============================================================

print("Opening annotation window...")
print("  S = Save & Next")
print("  N = Skip")
print("  P = Previous\n")

app = AnnotationApp(WORKSPACE_IMG, WORKSPACE_LBL)
# Out:
# Opening annotation window...
#   S = Save & Next
#   N = Skip
#   P = Previous
#
# ✓ [2198/2556] Saved: smsc_paddlechipfdc37c75lfjp.txt
# ✓ [2199/2556] Saved: smsc_sch5017nwb0608ak3610.txt
# ✓ [2200/2556] Saved: smsc_slc88b17d0421e771.txt
# ✓ [2201/2556] Saved: smsc_u8b3343244chcabtw.txt
# ✓ [2202/2556] Saved: smsc_ultrachip83c790qfp.txt
# ✓ [2203/2556] Saved: smsc_usb2227nu05.txt
# ✓ [2204/2556] Saved: smsc_usb2514bid1409a2p10409h2gaatccn.txt
# ✓ [2205/2556] Saved: smsc_usb2517jzxc1234a2804.txt
# ✓ [2206/2556] Saved: smsc_usb3315433v3pactw.txt
# ✓ [2207/2556] Saved: smsc_usx2065jzxd1216a3b19.txt
# ✓ [2208/2556] Saved: smsc_victory66slc90e66h0035l814.txt
# ✓ [2209/2556] Saved: sony_cxm4027r929hf5v.txt
# ✓ [2210/2556] Saved: sst_28ee011.txt
# ✓ [2211/2556] Saved: steptech_atetechnologyfedex346000200.txt
# ✓ [2212/2556] Saved: stm_32h750vbt6y7b552vqphlt7936.txt
# ✓ [2212/2556] Saved: steptech_atetechnologyfedex346000200.txt
# ✓ [2212/2556] Saved: stm_32h750vbt6y7b552vqphlt7936.txt
# ✓ [2213/2556] Saved: stm_33990a722.txt
# ✓ [2214/2556] Saved: stm_428rpk409.txt
# ✓ [2215/2556] Saved: stm_7812cvcc05jv6hn1328.txt
# ✓ [2216/2556] Saved: stm_784548s083f3p6.txt
# ✓ [2217/2556] Saved: stm_97l05a.txt
# ✓ [2218/2556] Saved: stm_L6911EB99070210malaysia.txt
# ✓ [2219/2556] Saved: stm_armzstm32f401rctbgh27tvqchngh.txt
# ✓ [2220/2556] Saved: stm_atic39a2c0835099011vb99mys.txt
# ✓ [2221/2556] Saved: stm_hcf4516bew99060310.txt
# ✓ [2222/2556] Saved: stm_itsst486dx4100st486dx4v1dhs.txt
# ✓ [2223/2556] Saved: stm_l6376pd3990j0140malaysia.txt
# ✓ [2224/2556] Saved: stm_l67177BA2YV5PHL99949.txt
# ✓ [2225/2556] Saved: stm_l7805cv6k01dv6chn433.txt
# ✓ [2226/2556] Saved: stm_l9302ad992mnvh99mys.txt
# ✓ [2227/2556] Saved: stm_l9302ad99412vh99320mys.txt
# ✓ [2228/2556] Saved: stm_m104197z233.txt
# ✓ [2229/2556] Saved: stm_m2210081sm010y.txt
# ✓ [2230/2556] Saved: stm_m29f010b.txt
# ✓ [2231/2556] Saved: stm_m41t559410.txt
# ✓ [2232/2556] Saved: stm_magnetarekiue06ab6r11gd0109italy.txt
# ✓ [2233/2556] Saved: stm_marvnd600spcz0ce435.txt
# ✓ [2234/2556] Saved: stm_msida2050acz0c0kxmar.txt
# ✓ [2235/2556] Saved: stm_mysvb325sp990a56322.txt
# ✓ [2236/2556] Saved: stm_n790a.txt
# ✓ [2237/2556] Saved: stm_riva128.txt
# ✓ [2238/2556] Saved: stm_smooth100295860991lwv1mys99831.txt
# ✓ [2239/2556] Saved: stm_smoothl62831399dhsvhmys99547.txt
# ✓ [2240/2556] Saved: stm_st1284017b342vuphl7b936.txt
# ✓ [2241/2556] Saved: stm_st7f0xf1m6.txt
# ✓ [2242/2556] Saved: stm_stg4000xa3sf3749819222x0120malta.txt
# ✓ [2243/2556] Saved: stm_stg4500xa2sf4202519hx3d0118korea.txt
# ✓ [2244/2556] Saved: stm_sti3400dcvdafap2ad9540korea.txt
# ✓ [2245/2556] Saved: stm_stm32f103rct6gh2bjvq.txt
# ✓ [2246/2556] Saved: stm_stm32f103ret6gq2919311chn.txt
# ✓ [2247/2556] Saved: stm_stm32f4298it678563vqphl7b706.txt
# ✓ [2248/2556] Saved: stm_stm32g431cbt6gq2681f9rchngq037.txt
# ✓ [2249/2556] Saved: stm_tda2003aczofyvwmar2308.txt
# ✓ [2250/2556] Saved: stm_tda7284r995b9409malaysia.txt
# ✓ [2251/2556] Saved: stm_tda7302L22db9214.txt
# ✓ [2252/2556] Saved: stm_tda7360w88kc841.txt
# ✓ [2253/2556] Saved: stm_vn772k9902yv3mys9933g.txt
# ✓ [2254/2556] Saved: stm_vnse010mhgk194429.txt
# ✓ [2255/2556] Saved: texas_1baf0klmb24.txt
# ✓ [2256/2556] Saved: texas_428ane555p.txt
# ✓ [2257/2556] Saved: texas_4can07msn74ls74an.txt
# ✓ [2258/2556] Saved: texas_66hnj3k.txt
# ✓ [2259/2556] Saved: texas_76ffy1k.txt
# ✓ [2260/2556] Saved: texas_81ckkeksn74lsdon.txt
# ✓ [2261/2556] Saved: texas_83c6e9m.txt
# ✓ [2262/2556] Saved: texas_98ad32j.txt
# ✓ [2263/2556] Saved: texas_b5072ci35a000wpg31.txt
# ✓ [2264/2556] Saved: texas_cd3215c007cccfdwgi.txt
# ✓ [2265/2556] Saved: texas_davincitms320dm6467ccut7730.txt
# ✓ [2266/2556] Saved: texas_gd75232.txt
# ✓ [2267/2556] Saved: texas_ha00.txt
# ✓ [2268/2556] Saved: texas_ha86.txt
# ✓ [2269/2556] Saved: texas_hb32.txt
# ✓ [2270/2556] Saved: texas_hct02.txt
# ✓ [2271/2556] Saved: texas_hct08.txt
# ✓ [2272/2556] Saved: texas_hct125.txt
# ✓ [2273/2556] Saved: texas_hct245.txt
# ✓ [2274/2556] Saved: texas_hct32.txt
# ✓ [2275/2556] Saved: texas_hct74.txt
# ✓ [2276/2556] Saved: texas_is154076tcdtvg4.txt
# ✓ [2277/2556] Saved: texas_lm35b69kevjtg5.txt
# ✓ [2278/2556] Saved: texas_mv3931.txt
# ✓ [2279/2556] Saved: texas_n355567ap09fg3.txt
# ✓ [2280/2556] Saved: texas_pcI1225pdv.txt
# ✓ [2281/2556] Saved: texas_tl062c.txt
# ✓ [2282/2556] Saved: texas_tl082c.txt
# ✓ [2283/2556] Saved: texas_tl594c.txt
# ✓ [2284/2556] Saved: texas_tlv62569.txt
# ✓ [2285/2556] Saved: texas_tms320c30gel.txt
# ✓ [2286/2556] Saved: texas_tpa1222ctdvho.txt
# ✓ [2287/2556] Saved: texas_x0b30k013dzk84.txt
# ✓ [2288/2556] Saved: toshiba_0025htc5051pjapan.txt
# ✓ [2289/2556] Saved: toshiba_1035tlp250.txt
# ✓ [2290/2556] Saved: toshiba_2108tlp2914gb.txt
# ✓ [2291/2556] Saved: toshiba_437p700a.txt
# ✓ [2292/2556] Saved: toshiba_74hc00ap914oh.txt
# ✓ [2293/2556] Saved: toshiba_74hct541a.txt
# ✓ [2294/2556] Saved: toshiba_87cp71f65979731h.txt
# ✓ [2295/2556] Saved: toshiba_8801htc40174bpjapan.txt
# ✓ [2296/2556] Saved: toshiba_8922htc4501bpjapan.txt
# ✓ [2297/2556] Saved: toshiba_8952hbtc4011bp.txt
# ✓ [2298/2556] Saved: toshiba_9101tb67s112pg.txt
# ✓ [2299/2556] Saved: toshiba_9105h4007ubf.txt
# ✓ [2300/2556] Saved: toshiba_9117h74hc04ap.txt
# ✓ [2301/2556] Saved: toshiba_9125uta7310pumsia.txt
# ✓ [2302/2556] Saved: toshiba_9143hbtc9153ap.txt
# ✓ [2303/2556] Saved: toshiba_9435uta8217pmsia.txt
# ✓ [2304/2556] Saved: toshiba_9447ea1tcd1251udjapan.txt
# ✓ [2305/2556] Saved: toshiba_9606htc9216pjapan.txt
# ✓ [2306/2556] Saved: toshiba_9709eaitmp90cm40af2692.txt
# ✓ [2307/2556] Saved: toshiba_9822htc9213pjapan.txt
# ✓ [2308/2556] Saved: toshiba_fivedegta7207p.txt
# ✓ [2309/2556] Saved: toshiba_fr27.txt
# ✓ [2310/2556] Saved: toshiba_japan1304hctc4050bp.txt
# ✓ [2311/2556] Saved: toshiba_japanta75902phd03k.txt
# ✓ [2312/2556] Saved: toshiba_japanta7g30p0410k.txt
# ✓ [2313/2556] Saved: toshiba_japantd6381n536aa11.txt
# ✓ [2314/2556] Saved: toshiba_t062003p8748.txt
# ✓ [2315/2556] Saved: toshiba_t08a.txt
# ✓ [2316/2556] Saved: toshiba_t2685a3c.txt
# ✓ [2317/2556] Saved: toshiba_t4758a9d20ebijapan.txt
# ✓ [2318/2556] Saved: toshiba_t6961bb83ghjapan.txt
# ✓ [2319/2556] Saved: toshiba_t6963cfg01011805hcl004966.txt
# ✓ [2320/2556] Saved: toshiba_t8292ghq095igfii.txt
# ✓ [2321/2556] Saved: toshiba_ta7288p9715k.txt
# ✓ [2322/2556] Saved: toshiba_ta7769pmsia8947b.txt
# ✓ [2323/2556] Saved: toshiba_ta8254bhq0945kb.txt
# ✓ [2324/2556] Saved: toshiba_ta8403kjapan0122k.txt
# ✓ [2325/2556] Saved: toshiba_ta8435hjapan808kb1i.txt
# ✓ [2326/2556] Saved: toshiba_ta8638n0815kjapan.txt
# ✓ [2327/2556] Saved: toshiba_ta8650n145kai.txt
# ✓ [2328/2556] Saved: toshiba_tb1229dnjapan14ka1t.txt
# ✓ [2329/2556] Saved: toshiba_tb2926ahq0916gbjapan.txt
# ✓ [2330/2556] Saved: toshiba_tb2929h00805gti.txt
# ✓ [2331/2556] Saved: toshiba_tb2930hq1301bg22.txt
# ✓ [2332/2556] Saved: toshiba_tb62254afng.txt
# ✓ [2333/2556] Saved: toshiba_tb6674pg5513002.txt
# ✓ [2334/2556] Saved: toshiba_tb675639ftg.txt
# ✓ [2335/2556] Saved: toshiba_tb67h450fng.txt
# ✓ [2336/2556] Saved: toshiba_tb9304fg621kb11.txt
# ✓ [2337/2556] Saved: toshiba_tc1660f9707h234.txt
# ✓ [2338/2556] Saved: toshiba_tc51832pl12japan.txt
# ✓ [2339/2556] Saved: toshiba_tc587fgat22ta00.txt
# ✓ [2340/2556] Saved: toshiba_tc8566f8747aaajapan.txt
# ✓ [2341/2556] Saved: toshiba_tc9164njapan954gh.txt
# ✓ [2342/2556] Saved: toshiba_tc9273n0109k32n.txt
# ✓ [2343/2556] Saved: toshiba_tc9299p9540h.txt
# ✓ [2344/2556] Saved: toshiba_tc9302af0088031hjapan.txt
# ✓ [2345/2556] Saved: toshiba_tcb502hq16244esi.txt
# ✓ [2346/2556] Saved: toshiba_td62504p8649k.txt
# ✓ [2347/2556] Saved: toshiba_tmp47c834nr067tx8007c919339.txt
# ✓ [2348/2556] Saved: toshiba_tmp68301af160823eazm0912zah.txt
# ✓ [2349/2556] Saved: toshiba_tmp6ehp22a21ac11w984bebz.txt
# ✓ [2350/2556] Saved: toshiba_tmp82c265bf109535beai.txt
# ✓ [2351/2556] Saved: toshiba_tmp90cn72df76279631eai.txt
# ✓ [2352/2556] Saved: toshiba_tmp90cr74df7357203236609501ebi.txt
# ✓ [2353/2556] Saved: toshiba_vhc164516.txt
# ✓ [2354/2556] Saved: trident_3dimage9750bcee01ma09m0050.txt
# ✓ [2355/2556] Saved: trident_4dwave-nxaccc02m3a15991539041593.txt
# ✓ [2356/2556] Saved: trident_9525dvd.txt
# ✓ [2357/2556] Saved: trident_9980bhf302d283110134.txt
# ✓ [2358/2556] Saved: trident_blade3d9880agac02h2h1500995029122094.txt
# ✓ [2358/2556] Saved: trident_9980bhf302d283110134.txt
# ✓ [2358/2556] Saved: trident_blade3d9880agac02h2h1500995029122094.txt
# ✓ [2359/2556] Saved: trident_blade3d9880turboaaec01d3817700994140tr17.txt
# ✓ [2360/2556] Saved: trident_bladet169960bhfe02d2w1810134.txt
# ✓ [2361/2556] Saved: trident_bladey649970bhfe02d2u161014651111821.txt
# ✓ [2362/2556] Saved: trident_cyber9320216tc1414600tsetmie28trfxas.txt
# ✓ [2363/2556] Saved: trident_cyber9385taagg01c1997800971717rfs.txt
# ✓ [2364/2556] Saved: trident_cyberblade178420baih01d41760009951.txt
# ✓ [2365/2556] Saved: trident_cyberbladexp99800hed02d57441d12251051965.txt
# ✓ [2366/2556] Saved: trident_tgui9440b322561tsh10trn6as.txt
# ✓ [2367/2556] Saved: trident_tgui9680b488251tsctmic04trt4as9604.txt
# ✓ [2368/2556] Saved: trident_tgui9682acab02m3864.txt
# ✓ [2369/2556] Saved: trident_tkd8001a467271935193.txt
# ✓ [2370/2556] Saved: trident_tvga8800brl1a4475nng89046950.txt
# ✓ [2371/2556] Saved: trident_tvga89000a0160008c9402b173641.txt
# ✓ [2372/2556] Saved: trident_tvga9000ajapan9132kk703.txt
# ✓ [2373/2556] Saved: trident_tvxpressaccc02mbr27993149060784.txt
# ✓ [2374/2556] Saved: trinamic_tmc239a5agermany.txt
# ✓ [2375/2556] Saved: tseng_et6000labsusa22c22u719.txt
# ✓ [2376/2556] Saved: tsi_92hd66b.txt
# ✓ [2377/2556] Saved: umc_um82c862f9149asna1476.txt
# ✓ [2378/2556] Saved: via_c3processorviac31p2aghz.txt
# ✓ [2379/2556] Saved: via_kt60003026cdtaiwan24a1002531.txt
# ✓ [2380/2556] Saved: via_vt12110208cdtaiwan2ha2017411.txt
# ✓ [2381/2556] Saved: via_vt1603a111bc0taiwan2ka2030738.txt
# ✓ [2382/2556] Saved: via_vt1603a1202cdtaiwan2ka3000364.txt
# ✓ [2383/2556] Saved: via_vt16340552cdtaiwan24a2008341.txt
# ✓ [2384/2556] Saved: via_vt17051215cdtaiwan2kb0090066.txt
# ✓ [2385/2556] Saved: via_vt1708b0834cdtaiwan2kb1910086.txt
# ✓ [2386/2556] Saved: via_vt1708b0933cdtaiwan2mb1910080.txt
# ✓ [2387/2556] Saved: via_vt17311127cdtaiwan2ua0009691.txt
# ✓ [2388/2556] Saved: via_vt1802p1213cdchina2ka3x00574.txt
# ✓ [2389/2556] Saved: via_vt1802p1225cdchina2ka3x00158.txt
# ✓ [2390/2556] Saved: via_vt1802p1235cdchina2ka3x00251.txt
# ✓ [2391/2556] Saved: via_vt1802p1238cdchina2ka3x10343.txt
# ✓ [2392/2556] Saved: via_vt1802s1404cdchina2ka3x00474.txt
# ✓ [2393/2556] Saved: via_vt188s091cdtaiwan2ka0009003.txt
# ✓ [2394/2556] Saved: via_vt2021111ocdtaiwan2kb1000005.txt
# ✓ [2395/2556] Saved: via_vt2021111ocdtaiwan2kb1000013.txt
# ✓ [2396/2556] Saved: via_vt6103l0613cdtaiwan2ha1450226.txt
# ✓ [2397/2556] Saved: via_vt6105041ocdtaiwan2hb4020413.txt
# ✓ [2398/2556] Saved: via_vt6106s0745cdtaiwan2hc000577r.txt
# ✓ [2399/2556] Saved: via_vt61300709cdtaiwan2ga2409262.txt
# ✓ [2400/2556] Saved: via_vt62020403cdtaiwan23a5010600.txt
# ✓ [2401/2556] Saved: via_vt6202l0403cdtaiwan23a6017900.txt
# ✓ [2402/2556] Saved: via_vt63060450cdtaiwan2hg1002863.txt
# ✓ [2403/2556] Saved: via_vt6308p074ocdtaiwan2ug4094561.txt
# ✓ [2404/2556] Saved: via_vt6308s1017cdtaiwan2ug4085691.txt
# ✓ [2405/2556] Saved: via_vt63200717cdtaiwan2ua1000124.txt
# ✓ [2406/2556] Saved: via_vt63301050cdtaiwan2ja3014661.txt
# ✓ [2407/2556] Saved: via_vt6421a0804cdtaiwan2ia0011611.txt
# ✓ [2408/2556] Saved: via_vt82350235cdtaiwan23a3424351.txt
# ✓ [2409/2556] Saved: via_vt82c586b9713cdtaiwan02601700.txt
# ✓ [2410/2556] Saved: via_vt82c597972ocdtaiwan02a05600.txt
# ✓ [2411/2556] Saved: via_vt82c694t0503cdtaiwan21800k4590.txt
# ✓ [2412/2556] Saved: via_vt83660109cdtaiwan12d008700.txt
# ✓ [2413/2556] Saved: via_vt83719h24cdtaiwan12008501.txt
# ✓ [2414/2556] Saved: via_vt8601a0732cetaiwan11k041091.txt
# ✓ [2415/2556] Saved: via_vt8601n0132cdtaiwan14f010661.txt
# ✓ [2416/2556] Saved: via_vt8601t0152cdtaiwan2ga5004561.txt
# ✓ [2417/2556] Saved: via_vt8601t0351cdtaiwan20a50a6681.txt
# ✓ [2418/2556] Saved: via_vt86330108cdtaiwan13c020300p.txt
# ✓ [2419/2556] Saved: vishay_0s0pa20010135.txt
# ✓ [2420/2556] Saved: vishay_2516t02805p24161sn0002.txt
# ✓ [2421/2556] Saved: vishay_bem16a.txt
# ✓ [2422/2556] Saved: vishay_bex4aa.txt
# ✓ [2423/2556] Saved: vishay_bz66a.txt
# ✓ [2424/2556] Saved: vishay_cnx82a.txt
# ✓ [2425/2556] Saved: vishay_cny65001jtk190884.txt
# ✓ [2426/2556] Saved: vishay_cny65a201jtk4.txt
# ✓ [2427/2556] Saved: vishay_cny65av601j19.txt
# ✓ [2428/2556] Saved: vishay_cny65av744j69.txt
# ✓ [2429/2556] Saved: vishay_cny65b040jtfk40883.txt
# ✓ [2430/2556] Saved: vishay_cny65b044jtk190884.txt
# ✓ [2431/2556] Saved: vishay_cny65tfk7220883.txt
# ✓ [2432/2556] Saved: vishay_cny65v235j19.txt
# ✓ [2433/2556] Saved: vishay_eb.txt
# ✓ [2434/2556] Saved: vishay_f1772410200001ufx2kmktac275vsh4010056.txt
# ✓ [2435/2556] Saved: vishay_f1772410200001ufx2kmktac275vsh4010056iec384142en132400ac250v0135.txt
# ✓ [2436/2556] Saved: vishay_gde.txt
# ✓ [2437/2556] Saved: vishay_gfp.txt
# ✓ [2438/2556] Saved: vishay_k3023p9jov307068.txt
# ✓ [2439/2556] Saved: vishay_k3023pv425h68.txt
# ✓ [2440/2556] Saved: vishay_m8s36b1910.txt
# ✓ [2441/2556] Saved: vishay_mcn0801560ktcc0625.txt
# ✓ [2442/2556] Saved: vishay_nolabelnopn.txt
# ✓ [2443/2556] Saved: vishay_powerpak10x12.txt
# ✓ [2444/2556] Saved: vishay_sa.txt
# ✓ [2445/2556] Saved: vishay_sm5s33a1536.txt
# ✓ [2446/2556] Saved: vishay_sm6a270622.txt
# ✓ [2447/2556] Saved: vishay_sm6a870408.txt
# ✓ [2448/2556] Saved: vishay_sm81910.txt
# ✓ [2449/2556] Saved: vishay_sm8a272308.txt
# ✓ [2450/2556] Saved: vishay_sm8s10a0204.txt
# ✓ [2451/2556] Saved: vishay_sm8s16a2031.txt
# ✓ [2452/2556] Saved: vishay_sm8s18a1935.txt
# ✓ [2453/2556] Saved: vishay_sm8s24a1432.txt
# ✓ [2454/2556] Saved: vishay_sm8s30a1502.txt
# ✓ [2455/2556] Saved: vishay_sm8s30a2218.txt
# ✓ [2456/2556] Saved: vishay_sm8s33a0650.txt
# ✓ [2457/2556] Saved: vishay_sm8s33a1516.txt
# ✓ [2458/2556] Saved: vishay_sm8s36a1505.txt
# ✓ [2459/2556] Saved: vishay_sm8s36a2031.txt
# ✓ [2460/2556] Saved: vishay_thedpakofvishay.txt
# ✓ [2461/2556] Saved: vishay_zg.txt
# ✓ [2462/2556] Saved: vli_vl812q71205esb0c4214200.txt
# ✓ [2463/2556] Saved: vli_vl817q71745b0942m3600.txt
# ✓ [2464/2556] Saved: volterra_vt1000s9446vtu422501.txt
# ✓ [2465/2556] Saved: wch_003f4u602c39.txt
# ✓ [2466/2556] Saved: wch_ch32l103c6t6812812301.txt
# ✓ [2467/2556] Saved: wch_ch32v003f4p612309c34.txt
# ✓ [2468/2556] Saved: wch_ch32v003f4p6412304c51.txt
# ✓ [2469/2556] Saved: wch_ch32v003f4p6412309c34.txt
# ✓ [2470/2556] Saved: wch_ch32v003f4p6412309c44.txt
# ✓ [2471/2556] Saved: wch_ch32v003f4p6412314e22.txt
# ✓ [2472/2556] Saved: wch_ch32v203f6p631170xc10.txt
# ✓ [2473/2556] Saved: wch_ch32v203f8p631170xc25.txt
# ✓ [2474/2556] Saved: wch_ch32v3056gbu631103fe22.txt
# ✓ [2475/2556] Saved: wch_ch32x033f8p812604d2.txt
# ✓ [2476/2556] Saved: wch_ch32x035c8t6812612e17.txt
# ✓ [2477/2556] Saved: wch_ch3401202686303.txt
# ✓ [2478/2556] Saved: wch_ch340c.txt
# ✓ [2479/2556] Saved: wch_ch340c205665810.txt
# ✓ [2480/2556] Saved: wch_ch340c205665820.txt
# ✓ [2481/2556] Saved: wch_ch340n411406c88.txt
# ✓ [2482/2556] Saved: wch_ch340t202686303.txt
# ✓ [2483/2556] Saved: wch_ch341e202906c34.txt
# ✓ [2484/2556] Saved: wch_ch345qc01h1e3.txt
# ✓ [2485/2556] Saved: wch_ch360a50851d515.txt
# ✓ [2486/2556] Saved: wch_ch375b202386a46.txt
# ✓ [2487/2556] Saved: wch_ch376s206265231.txt
# ✓ [2488/2556] Saved: wch_ch376t208276894.txt
# ✓ [2489/2556] Saved: wch_ch395054318e3s2.txt
# ✓ [2490/2556] Saved: wch_ch455h209405403.txt
# ✓ [2491/2556] Saved: wch_ch554t405815730.txt
# ✓ [2492/2556] Saved: wch_ch912150910e265.txt
# ✓ [2493/2556] Saved: wch_ch912150910e2652.txt
# ✓ [2494/2556] Saved: weitek_wtl2010jc2a8712g.txt
# ✓ [2495/2556] Saved: winbond_25q16jwniq2406.txt
# ✓ [2496/2556] Saved: winbond_25q32fvsig1532.txt
# ✓ [2497/2556] Saved: winbond_25q64cvsig1130.txt
# ✓ [2498/2556] Saved: winbond_25q64fwsig.txt
# ✓ [2499/2556] Saved: winbond_25q64fwsig1445.txt
# ✓ [2500/2556] Saved: winbond_25q64jvsiq2327.txt
# ✓ [2501/2556] Saved: winbond_25q64jwsiq2116.txt
# ✓ [2502/2556] Saved: winbond_25q80bvsig.txt
# ✓ [2503/2556] Saved: winbond_25q80bvsig1150.txt
# ✓ [2504/2556] Saved: winbond_25x05clmig1417.txt
# ✓ [2505/2556] Saved: winbond_25x10bvnig1126.txt
# ✓ [2506/2556] Saved: winbond_286855af91195gwk.txt
# ✓ [2507/2556] Saved: winbond_29922pf824ab2808514025a.txt
# ✓ [2508/2556] Saved: winbond_smartiow83l518d362gbsb.txt
# ✓ [2509/2556] Saved: winbond_w24129aj12807ab27385010522xd.txt
# ✓ [2510/2556] Saved: winbond_w26p240af67385c273119901zh.txt
# ✓ [2511/2556] Saved: winbond_w81181ad011ah06b.txt
# ✓ [2512/2556] Saved: winbond_w83194r58a29508310n1021gab.txt
# ✓ [2513/2556] Saved: winbond_w83194r630a293328500200bd.txt
# ✓ [2514/2556] Saved: winbond_w83301gr242109202431gdnb.txt
# ✓ [2515/2556] Saved: winbond_w83303ag3644490721gbra.txt
# ✓ [2516/2556] Saved: winbond_w83303d234133902348gera.txt
# ✓ [2517/2556] Saved: winbond_w83304d250809502521gbra.txt
# ✓ [2518/2556] Saved: winbond_w83310ds.txt
# ✓ [2519/2556] Saved: winbond_w83391tg26305360644ga.txt
# ✓ [2520/2556] Saved: winbond_w83747p9048tjwz.txt
# ✓ [2521/2556] Saved: winbond_w837658p505ae14373690.txt
# ✓ [2522/2556] Saved: winbond_w83765p246na412910.txt
# ✓ [2523/2556] Saved: winbond_w83768f420ad14d52980.txt
# ✓ [2524/2556] Saved: winbond_w83768f5040a14484680.txt
# ✓ [2525/2556] Saved: winbond_w83910f2381ca2212835025a.txt
# ✓ [2526/2556] Saved: winbond_w83l5180362gbsb.txt
# ✓ [2527/2556] Saved: winbond_w86c551924ac1916390.txt
# ✓ [2528/2556] Saved: winbond_w9864g6kh612128h6112jn600zu.txt
# ✓ [2529/2556] Saved: winbond_w9920a1434aa24230240.txt
# ✓ [2530/2556] Saved: winbond_wpce775ca0dg4814b041aa2819nbfa.txt
# ⏭️  Skipped: wit_mx25l25673gm2108g8e982503l191127.png
# ✓ [2531/2556] Saved: wurth_p528gee.txt
# ✓ [2532/2556] Saved: wuxi.txt
# ✓ [2533/2556] Saved: wuxi_btj706stb2525sp4153.txt
# ✓ [2534/2556] Saved: wuxi_btj7606stb2525.txt
# ✓ [2535/2556] Saved: wuxi_btj7606stb2525sp4153.txt
# ✓ [2536/2556] Saved: wuxi_btj7616st62526sp4153.txt
# ✓ [2537/2556] Saved: wuxi_btj7616st62526sp41532.txt
# ✓ [2538/2556] Saved: wuxi_btj7816st62525sp4153.txt
# ✓ [2539/2556] Saved: wuxi_btj7816st62526sp415.txt
# ✓ [2540/2556] Saved: wuxi_btj9415.txt
# ✓ [2541/2556] Saved: wuxi_btj9449ssa2511.txt
# ✓ [2542/2556] Saved: wuxi_btj9653sca2531.txt
# ✓ [2543/2556] Saved: wuxi_btj9669ssa2449.txt
# ✓ [2544/2556] Saved: wuxi_btjt816st62525sp4153.txt
# ✓ [2545/2556] Saved: xilinx_spartan6csg324b1v1713d4585387a.txt
# ✓ [2546/2556] Saved: xmc_0h128ah1gp1w94400091930c.txt
# ✓ [2547/2556] Saved: yamaha_japanyss216b9544ab0k.txt
# ✓ [2548/2556] Saved: yamaha_ym3812f.txt
# ✓ [2549/2556] Saved: zarlink_mt8816ap2077929333ae.txt
# ✓ [2550/2556] Saved: zarlink_mt9074ap5587859930ae.txt
# ✓ [2551/2556] Saved: zarlink_mt9075bp2396150227ae.txt
