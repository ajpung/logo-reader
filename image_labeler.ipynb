# %%
# ============================================================
# STEP 1: Verify workspace exists
# ============================================================

import os
import shutil

COMPONENTS_DIR = './components/'
WORKSPACE_IMG  = './annotation_workspace/images/train'
WORKSPACE_LBL  = './annotation_workspace/labels/train'

os.makedirs(WORKSPACE_IMG, exist_ok=True)
os.makedirs(WORKSPACE_LBL, exist_ok=True)

# Copy images if workspace is empty
if len(os.listdir(WORKSPACE_IMG)) == 0:
    print("Copying images to workspace...")
    for f in os.listdir(COMPONENTS_DIR):
        if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
            shutil.copy(os.path.join(COMPONENTS_DIR, f), WORKSPACE_IMG)

img_count = len([f for f in os.listdir(WORKSPACE_IMG) if f.lower().endswith(('.png','.jpg','.jpeg','.bmp'))])
lbl_count = len([f for f in os.listdir(WORKSPACE_LBL) if f.endswith('.txt')])

print(f"✓ Images:      {img_count}")
print(f"✓ Annotations: {lbl_count}")
print(f"✓ Remaining:   {img_count - lbl_count}")
# Out:
# ✓ Images:      2556
# ✓ Annotations: 0
# ✓ Remaining:   2556

# %%
# ============================================================
# STEP 2: Standalone Tkinter Annotation Tool - FIXED
# ============================================================

import tkinter as tk
from PIL import Image, ImageTk
import os

class AnnotationApp:
    def __init__(self, image_dir, label_dir):
        self.image_dir = image_dir
        self.label_dir = label_dir
        os.makedirs(label_dir, exist_ok=True)
        
        self.image_files = sorted([
            f for f in os.listdir(image_dir)
            if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))
        ])
        
        # Auto-resume
        self.current_idx = len(self.image_files)
        for i, f in enumerate(self.image_files):
            label_file = os.path.splitext(f)[0] + '.txt'
            if not os.path.exists(os.path.join(label_dir, label_file)):
                self.current_idx = i
                break
        
        self.box_start = None
        self.box_end = None
        self.dragging = False
        
        self.current_img = None
        self.display_img = None
        self.img_offset_x = 0
        self.img_offset_y = 0
        self.scale = 1.0
        
        self._build_ui()
        
        # FIXED: Wait for window to actually render, THEN load first image
        # root.after() schedules _load_image to run after the event loop starts
        self.root.after(100, self._load_image)
        
        self.root.mainloop()
    
    def _count_annotated(self):
        return sum(1 for f in self.image_files
                   if os.path.exists(os.path.join(self.label_dir,
                      os.path.splitext(f)[0] + '.txt')))
    
    def _build_ui(self):
        self.root = tk.Tk()
        self.root.title('Logo Annotation Tool')
        self.root.configure(bg='#1e1e1e')
        
        screen_w = self.root.winfo_screenwidth()
        screen_h = self.root.winfo_screenheight()
        win_w = min(900, screen_w - 100)
        win_h = min(950, screen_h - 50)
        self.root.geometry(f'{win_w}x{win_h}')
        self.root.resizable(True, True)
        
        # --- Progress label ---
        self.progress_var = tk.StringVar(value='Loading...')
        tk.Label(
            self.root, textvariable=self.progress_var,
            bg='#1e1e1e', fg='white', font=('Consolas', 11, 'bold')
        ).pack(side='top', pady=(8, 2))
        
        # --- Canvas ---
        canvas_frame = tk.Frame(self.root, bg='#1e1e1e')
        canvas_frame.pack(side='top', fill='both', expand=True, padx=10)
        
        self.canvas = tk.Canvas(canvas_frame, bg='#111111', highlightthickness=0)
        self.canvas.pack(fill='both', expand=True)
        
        self.canvas.bind('<ButtonPress-1>',   self._on_mouse_down)
        self.canvas.bind('<B1-Motion>',       self._on_mouse_drag)
        self.canvas.bind('<ButtonRelease-1>', self._on_mouse_up)
        
        # Keyboard
        self.root.bind('<s>', lambda e: self._save_and_next())
        self.root.bind('<S>', lambda e: self._save_and_next())
        self.root.bind('<n>', lambda e: self._skip())
        self.root.bind('<N>', lambda e: self._skip())
        self.root.bind('<p>', lambda e: self._previous())
        self.root.bind('<P>', lambda e: self._previous())
        
        # --- Buttons ---
        btn_frame = tk.Frame(self.root, bg='#1e1e1e')
        btn_frame.pack(side='bottom', pady=10)
        
        btn_kw = {'font': ('Consolas', 12, 'bold'), 'width': 16,
                  'relief': 'flat', 'cursor': 'hand2', 'bd': 0}
        
        tk.Button(btn_frame, text='✓  Save & Next  [S]',
                  bg='#2ecc71', fg='white', activebackground='#27ae60', activeforeground='white',
                  command=self._save_and_next, **btn_kw
        ).pack(side='left', padx=8)
        
        tk.Button(btn_frame, text='⏭  Skip  [N]',
                  bg='#e67e22', fg='white', activebackground='#d35400', activeforeground='white',
                  command=self._skip, **btn_kw
        ).pack(side='left', padx=8)
        
        tk.Button(btn_frame, text='◀  Previous  [P]',
                  bg='#3498db', fg='white', activebackground='#2980b9', activeforeground='white',
                  command=self._previous, **btn_kw
        ).pack(side='left', padx=8)
        
        # --- Status bar ---
        self.status_var = tk.StringVar(value='Loading...')
        tk.Label(
            self.root, textvariable=self.status_var,
            bg='#2c2c2c', fg='#aaaaaa', font=('Consolas', 9)
        ).pack(side='bottom', fill='x')
    
    # ----------------------------------------------------------
    # Mouse handlers
    # ----------------------------------------------------------
    
    def _on_mouse_down(self, event):
        self.box_start = (event.x, event.y)
        self.box_end = None
        self.dragging = True
        self._redraw_canvas()
    
    def _on_mouse_drag(self, event):
        if self.dragging:
            self.box_end = (event.x, event.y)
            self._redraw_canvas()
    
    def _on_mouse_up(self, event):
        self.dragging = False
        if self.box_start and self.box_end:
            if abs(self.box_end[0] - self.box_start[0]) < 5 or \
               abs(self.box_end[1] - self.box_start[1]) < 5:
                self.box_start = None
                self.box_end = None
                self._redraw_canvas()
                return
            self.status_var.set('Box drawn!  Press S or click "Save & Next"')
        self._redraw_canvas()
    
    # ----------------------------------------------------------
    # Image loading
    # ----------------------------------------------------------
    
    def _load_image(self):
        if self.current_idx >= len(self.image_files):
            self.progress_var.set('🎉  ALL DONE!')
            self.status_var.set(f'All {len(self.image_files)} images annotated.')
            self.canvas.delete('all')
            return
        
        img_file = self.image_files[self.current_idx]
        self.current_img = Image.open(os.path.join(self.image_dir, img_file)).convert('RGB')
        
        # Progress text
        done = self._count_annotated()
        total = len(self.image_files)
        self.progress_var.set(
            f'[{self.current_idx+1}/{total}]  {img_file}  |  {done}/{total} done ({done/total*100:.0f}%)'
        )
        
        # Reset box
        self.box_start = None
        self.box_end = None
        
        # Get actual canvas size (guaranteed valid here because of after())
        self.root.update_idletasks()
        canvas_w = self.canvas.winfo_width()
        canvas_h = self.canvas.winfo_height()
        
        # Safety check - fallback if still 0 for some reason
        if canvas_w <= 1 or canvas_h <= 1:
            canvas_w = 800
            canvas_h = 800
        
        # Fit image into canvas keeping aspect ratio
        img_w, img_h = self.current_img.size
        self.scale = min(canvas_w / img_w, canvas_h / img_h)
        
        new_w = max(1, int(img_w * self.scale))
        new_h = max(1, int(img_h * self.scale))
        
        self.img_offset_x = (canvas_w - new_w) // 2
        self.img_offset_y = (canvas_h - new_h) // 2
        
        self.display_img = self.current_img.resize((new_w, new_h), Image.LANCZOS)
        
        # Load existing annotation if present
        label_file = os.path.splitext(img_file)[0] + '.txt'
        label_path = os.path.join(self.label_dir, label_file)
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                parts = f.readline().strip().split()
                if len(parts) == 5:
                    _, xc, yc, w, h = map(float, parts)
                    x1 = int((xc - w/2) * img_w * self.scale + self.img_offset_x)
                    y1 = int((yc - h/2) * img_h * self.scale + self.img_offset_y)
                    x2 = int((xc + w/2) * img_w * self.scale + self.img_offset_x)
                    y2 = int((yc + h/2) * img_h * self.scale + self.img_offset_y)
                    self.box_start = (x1, y1)
                    self.box_end   = (x2, y2)
            self.status_var.set('Already annotated. Draw new box to overwrite, or press N to skip.')
        else:
            self.status_var.set('Click and drag on the image to draw a box around the logo')
        
        self._redraw_canvas()
    
    # ----------------------------------------------------------
    # Canvas drawing
    # ----------------------------------------------------------
    
    def _redraw_canvas(self):
        self.canvas.delete('all')
        
        if self.display_img is None:
            return
        
        # Base image
        self.tk_img = ImageTk.PhotoImage(self.display_img)
        self.canvas.create_image(self.img_offset_x, self.img_offset_y,
                                 anchor='nw', image=self.tk_img)
        
        # Box overlay
        if self.box_start and self.box_end:
            x1 = min(self.box_start[0], self.box_end[0])
            y1 = min(self.box_start[1], self.box_end[1])
            x2 = max(self.box_start[0], self.box_end[0])
            y2 = max(self.box_start[1], self.box_end[1])
            
            # Fill
            self.canvas.create_rectangle(x1, y1, x2, y2,
                                         outline='', fill='lime', stipple='gray25')
            # Border
            self.canvas.create_rectangle(x1, y1, x2, y2,
                                         outline='lime', width=3, fill='')
            # Label
            self.canvas.create_text(x1 + 5, max(y1 - 14, 2),
                                    text='LOGO', fill='lime',
                                    font=('Consolas', 12, 'bold'), anchor='nw')
    
    # ----------------------------------------------------------
    # Actions
    # ----------------------------------------------------------
    
    def _canvas_to_image_coords(self, cx, cy):
        ix = (cx - self.img_offset_x) / self.scale
        iy = (cy - self.img_offset_y) / self.scale
        return ix, iy
    
    def _save_and_next(self):
        if self.box_start is None or self.box_end is None:
            self.status_var.set('⚠️  No box drawn! Click and drag first.')
            return
        
        x1_img, y1_img = self._canvas_to_image_coords(*self.box_start)
        x2_img, y2_img = self._canvas_to_image_coords(*self.box_end)
        x1_img, x2_img = min(x1_img, x2_img), max(x1_img, x2_img)
        y1_img, y2_img = min(y1_img, y2_img), max(y1_img, y2_img)
        
        img_w, img_h = self.current_img.size
        x_center = max(0, min(1, ((x1_img + x2_img) / 2) / img_w))
        y_center = max(0, min(1, ((y1_img + y2_img) / 2) / img_h))
        width    = max(0, min(1, (x2_img - x1_img) / img_w))
        height   = max(0, min(1, (y2_img - y1_img) / img_h))
        
        img_file = self.image_files[self.current_idx]
        label_file = os.path.splitext(img_file)[0] + '.txt'
        label_path = os.path.join(self.label_dir, label_file)
        with open(label_path, 'w') as f:
            f.write(f"0 {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")
        
        print(f"✓ [{self._count_annotated()}/{len(self.image_files)}] Saved: {label_file}")
        
        self.current_idx += 1
        self._load_image()
    
    def _skip(self):
        print(f"⏭️  Skipped: {self.image_files[self.current_idx]}")
        self.current_idx += 1
        self._load_image()
    
    def _previous(self):
        if self.current_idx > 0:
            self.current_idx -= 1
            self._load_image()
        else:
            self.status_var.set('⚠️  Already at first image')


# ============================================================
# LAUNCH
# ============================================================

print("Opening annotation window...")
print("  S = Save & Next")
print("  N = Skip")
print("  P = Previous\n")

app = AnnotationApp(WORKSPACE_IMG, WORKSPACE_LBL)
# Out:
# Opening annotation window...
#   S = Save & Next
#   N = Skip
#   P = Previous
#
# ✓ [1/2556] Saved: 3com_8350019245546382402att835001.txt
# ✓ [2/2556] Saved: 3com_910a013com48076300100112700tac18710.txt
# ✓ [3/2556] Saved: 3com_910a01400763001dd1127.txt
# ✓ [4/2556] Saved: 3com_920bro340057900315189.txt
# ✓ [5/2556] Saved: 3com_920bro53com400570058636ct0027p16broadcom5904.txt
# ✓ [6/2556] Saved: 3com_920bro54005790058636.txt
# ✓ [7/2556] Saved: 3com_920bro63com40060800650401cs0037p17broadcom5904.txt
# ✓ [8/2556] Saved: 3com_920bro640060800650401.txt
# ✓ [9/2556] Saved: 3com_920st063com400664006mjc1touac0426.txt
# ✓ [10/2556] Saved: 3com_920st063com483664106mfcbsduac8227.txt
# ✓ [11/2556] Saved: 3com_920st06400664006.txt
# ✓ [12/2556] Saved: 3com_ad1807jsere38132x.txt
# ✓ [13/2556] Saved: 3com_bcm5701tkhb.txt
# ✓ [14/2556] Saved: 3com_bcm5701tkhbtk0308.txt
# ✓ [15/2556] Saved: 3com_marvell920mv00400780001.txt
# ✓ [16/2556] Saved: 3com_marvell920mvco400760001480696260322atp.txt
# ✓ [17/2556] Saved: 3com_paralleltasking4001300029528s22498553.txt
# ✓ [18/2556] Saved: 3com_paralleltasking4001300039616s.txt
# ✓ [19/2556] Saved: 3com_paralleltasking4003360059705s.txt
# ✓ [20/2556] Saved: 3com_paralleltaskingii4004830049939t_qfp.txt
# ✓ [21/2556] Saved: 3com_paralleltaskingii4005020039820s.txt
# ✓ [22/2556] Saved: 3dfx_30003550017010f1061410991220005.txt
# ✓ [23/2556] Saved: 3dfx_3550024030f2666810c002520005.txt
# ✓ [24/2556] Saved: 3dfx_3550025001f1134910993920005.txt
# ✓ [25/2556] Saved: 3dfx_3550026220f251181as003120005.txt
# ✓ [26/2556] Saved: 3dfx_3550026220f277393as003420005.txt
# ✓ [27/2556] Saved: 3dfx_355024030fx666010c002520005.txt
# ✓ [28/2556] Saved: 3dfx_500000102ba25411fbi962020001.txt
# ✓ [29/2556] Saved: 3dfx_500000201ba57951tmu962320001.txt
# ✓ [30/2556] Saved: 3dfx_500000303bc96791fb19736.txt
# ✓ [31/2556] Saved: 3dfx_500000402f0036011tmu980820005.txt
# ✓ [32/2556] Saved: 3dfx_500000504bc63981fjr973120001.txt
# ✓ [33/2556] Saved: 3dfx_500000901d1763500ck9811.txt
# ✓ [34/2556] Saved: 3dfx_500000901d1775000ck981020004taiwan1001.txt
# ✓ [35/2556] Saved: 3dfx_500001001D1738400be981020004.txt
# ✓ [36/2556] Saved: 3dfx_500001001d1738400be9810200042.txt
# ✓ [37/2556] Saved: 3dfx_500001001d1738400be981020004taiwan1001.txt
# ✓ [38/2556] Saved: 3dfx_500001001d1869400be981220004-2.txt
# ✓ [39/2556] Saved: 3dfx_500001001d1869400be98122004taiwan.txt
# ✓ [40/2556] Saved: 3dfx_500001304f104981ban993320005.txt
# ✓ [41/2556] Saved: 3dfx_vsa100igf6078320049taiwan.txt
# ✓ [42/2556] Saved: acer_m1101wp9447y.txt
# ✓ [43/2556] Saved: acer_m12038y2003v1.txt
# ✓ [43/2556] Saved: acer_m1101wp9447y.txt
# ✓ [43/2556] Saved: acer_m12038y2003v1.txt
# ✓ [44/2556] Saved: acer_m1207160y2011.txt
# ✓ [45/2556] Saved: acer_m1411a0304101mio.txt
# ✓ [46/2556] Saved: acer_m2201.txt
# ✓ [47/2556] Saved: acer_m3125.txt
# ✓ [48/2556] Saved: acer_m3125nnr9112wg17379.txt
# ✓ [49/2556] Saved: acer_m5105a29117ts6.txt
# ✓ [50/2556] Saved: acer_m5105a29124ts6.txt
# ✓ [51/2556] Saved: acer_m5105a3e9212ts6a21291.txt
# ✓ [52/2556] Saved: acer_m5105a439431ts5aa5354e.txt
# ✓ [53/2556] Saved: acer_m5105a4e9436_QFP.txt
# ✓ [54/2556] Saved: acer_m5105a4e9436ts5aa7315e.txt
# ✓ [55/2556] Saved: acer_m5105a4e9441.txt
# ✓ [56/2556] Saved: acer_m5105a4e9441ts2aa7811e.txt
# ✓ [57/2556] Saved: acer_m5105a4eaa7811e.txt
# ✓ [58/2556] Saved: acer_m6357.txt
# ✓ [59/2556] Saved: acer_m6357a1japanneo9445w50003.txt
# ✓ [60/2556] Saved: acer_mi2038y2003vi.txt
# ✓ [61/2556] Saved: acer_sioa045001as9134.txt
# ✓ [62/2556] Saved: actel_a1010bpl68c9448.txt
# ✓ [63/2556] Saved: actel_a1010bpl68c9648.txt
# ✓ [64/2556] Saved: actel_a1010bpl68c9705.txt
# ✓ [65/2556] Saved: actel_a1010pl68c8940.txt
# ✓ [66/2556] Saved: actel_a1020apl68c9037.txt
# ✓ [67/2556] Saved: actel_a1020apl84c9451.txt
# ✓ [68/2556] Saved: actel_a1020bpl4419749.txt
# ✓ [69/2556] Saved: actel_a1020bpl84c0313.txt
# ✓ [70/2556] Saved: actel_a1020bpl84c9707.txt
# ✓ [71/2556] Saved: actel_a1020bpl84c9819.txt
# ✓ [72/2556] Saved: actel_a1225apq100c9826.txt
# ✓ [73/2556] Saved: actel_a1460a1pq208c0034.txt
# ✓ [74/2556] Saved: actel_a40mx02pl4410437.txt
# ✓ [75/2556] Saved: actel_a42mx16m1pq100m0419f.txt
# ✓ [76/2556] Saved: actel_a54sx32atq14410325.txt
# ✓ [77/2556] Saved: actel_proasic3a3p250fgg2560626.txt
# ✓ [78/2556] Saved: actel_proasic3a3p250pqg2081936.txt
# ✓ [79/2556] Saved: actel_proasic3ea3pe1500pqg2081323za250471.txt
# ✓ [80/2556] Saved: actel_proasica500k050bg2720830.txt
# ✓ [81/2556] Saved: actel_proasicplusapa150pq208es.txt
# ✓ [82/2556] Saved: actel_proasicplusapa150pqg2081517r50kl.txt
# ✓ [83/2556] Saved: actel_proasicplusapa300pq2080420.txt
# ✓ [84/2556] Saved: adaptec_5800apaqea836.txt
# ✓ [85/2556] Saved: adaptec_7856taqeb712.txt
# ✓ [86/2556] Saved: adaptec_aic010flzc940.txt
# ✓ [87/2556] Saved: adaptec_aic3370pbkkb018pt.txt
# ✓ [88/2556] Saved: adaptec_aic3410pbkkb428pt.txt
# ✓ [89/2556] Saved: adaptec_aic4600lsd318ar.txt
# ✓ [90/2556] Saved: adaptec_aic560clta043.txt
# ✓ [91/2556] Saved: adaptec_aic565llsa210.txt
# ✓ [92/2556] Saved: adaptec_aic575lasa113.txt
# ✓ [93/2556] Saved: adaptec_aic580allsb209.txt
# ✓ [94/2556] Saved: adaptec_aic6251alzga313.txt
# ✓ [95/2556] Saved: adaptec_aic6260alzga145.txt
# ✓ [96/2556] Saved: adaptec_aic63600ckea809711911d350korea.txt
# ✓ [97/2556] Saved: adaptec_aic7110qgkkd603.txt
# ✓ [98/2556] Saved: adaptec_aic7770peqka438.txt
# ✓ [99/2556] Saved: adaptec_aic7850qbqwa432.txt
# ✓ [100/2556] Saved: adaptec_aic7880paqwa714.txt
# ✓ [101/2556] Saved: adaptec_aic7880pbqwab14.txt
# ✓ [102/2556] Saved: adaptec_aic7890abaqec916.txt
# ✓ [102/2556] Saved: adaptec_aic7880paqwa714.txt
# ✓ [102/2556] Saved: adaptec_aic7880pbqwab14.txt
# ✓ [102/2556] Saved: adaptec_aic7890abaqec916.txt
# ✓ [103/2556] Saved: adaptec_aic7892bbqec108.txt
# ✓ [104/2556] Saved: adaptec_aic7896naqee031.txt
# ✓ [105/2556] Saved: adaptec_aic78990aqec931.txt
# ✓ [106/2556] Saved: adaptec_aic7901xbqxb735.txt
# ✓ [107/2556] Saved: adaptec_aic_6360lckea411.txt
# ✓ [108/2556] Saved: adaptec_tbqeb92974221.txt
# ✓ [109/2556] Saved: akm_0824jbhjapan.txt
# ✓ [110/2556] Saved: akm_4385et2n925.txt
# ✓ [111/2556] Saved: akm_4430et8e523.txt
# ✓ [112/2556] Saved: akm_7755en618c.txt
# ✓ [113/2556] Saved: akm_ak4118aeq2238has.txt
# ✓ [114/2556] Saved: akm_ak41912922174ae.txt
# ✓ [115/2556] Saved: akm_ak4191eq2024vze.txt
# ✓ [116/2556] Saved: akm_ak4191eq2217vae.txt
# ✓ [117/2556] Saved: akm_ak4391eq2024vze.txt
# ✓ [118/2556] Saved: akm_ak4395eq0825ezw.txt
# ✓ [119/2556] Saved: akm_ak4458vn1425ezc.txt
# ✓ [120/2556] Saved: akm_ak4490eq1437ebe.txt
# ✓ [121/2556] Saved: akm_ak4490req2129vzj.txt
# ✓ [122/2556] Saved: akm_ak4493seo2129vzj.txt
# ✓ [123/2556] Saved: akm_ak4499eqxxxxxxxverita.txt
# ✓ [124/2556] Saved: akm_ak4499exed1234xyz.txt
# ✓ [125/2556] Saved: akm_ak4499exeq2145h7e.txt
# ✓ [126/2556] Saved: akm_ak4499exeq2236vae.txt
# ✓ [127/2556] Saved: akm_ak4499exeq2316vae.txt
# ✓ [128/2556] Saved: akm_ak4522vf0c511n.txt
# ✓ [129/2556] Saved: akm_ak4522vf1c109n.txt
# ✓ [130/2556] Saved: akm_ak4523vf064c0335n.txt
# ✓ [131/2556] Saved: akm_ak45278vq0407jaajapan.txt
# ✓ [132/2556] Saved: akm_ak4527vq0135jaajapan.txt
# ✓ [133/2556] Saved: akm_ak4528vf131b0520h.txt
# ✓ [134/2556] Saved: akm_ak4571vq0808jah.txt
# ✓ [135/2556] Saved: akm_ak4586vq0843jaa.txt
# ✓ [136/2556] Saved: akm_ak4642a643b.txt
# ✓ [137/2556] Saved: akm_ak5351vf5n644n.txt
# ✓ [138/2556] Saved: akm_ak5383vf128n0520n.txt
# ✓ [139/2556] Saved: akm_ak53858yx049e1445h.txt
# ✓ [140/2556] Saved: akm_ak5394avs003c0231n.txt
# ✓ [141/2556] Saved: akm_ak5394avs929c1927n.txt
# ✓ [142/2556] Saved: akm_ak7709vq2304sae.txt
# ✓ [143/2556] Saved: akm_ak85910610ezm.txt
# ✓ [144/2556] Saved: akm_japanak5393vs020n0150n.txt
# ✓ [145/2556] Saved: akm_veritaak4490eqxxxxxxx.txt
# ✓ [146/2556] Saved: ali_m1218.txt
# ✓ [147/2556] Saved: ali_m1219a19430ts5aa5637.txt
# ✓ [148/2556] Saved: ali_m1419a19303ts6.txt
# ✓ [149/2556] Saved: ali_m1431a29440ts6.txt
# ✓ [150/2556] Saved: ali_m1435a19412ts7.txt
# ✓ [151/2556] Saved: ali_m1445a29404ts6.txt
# ✓ [152/2556] Saved: ali_m1451a19437ts6.txt
# ✓ [153/2556] Saved: ali_m1487b19602ts6.txt
# ✓ [154/2556] Saved: ali_m1489a19602ts6.txt
# ✓ [155/2556] Saved: ali_m1511a19603ts6.txt
# ✓ [156/2556] Saved: ali_m1512a19546ts6.txt
# ✓ [157/2556] Saved: ali_m1535a10404th07.txt
# ✓ [158/2556] Saved: ali_m1541a1100mhz.txt
# ✓ [159/2556] Saved: ali_m1543cb10023tm05.txt
# ✓ [160/2556] Saved: ali_m1561a10019tb08.txt
# ✓ [161/2556] Saved: ali_m1621ai100mhz.txt
# ✓ [162/2556] Saved: ali_m5111a19449a5.txt
# ✓ [163/2556] Saved: ali_m5113a20145ts05.txt
# ✓ [164/2556] Saved: ali_m5123a9635ts62.txt
# ✓ [165/2556] Saved: ali_m5135b19841tm05.txt
# ✓ [166/2556] Saved: ali_m5143a19721ts6.txt
# ✓ [167/2556] Saved: ali_m5213na19434ts5.txt
# ✓ [168/2556] Saved: ali_m5215na29433ts5.txt
# ✓ [169/2556] Saved: ali_m5273a10411ts05.txt
# ✓ [170/2556] Saved: ali_m5283d10740tu07.txt
# ✓ [171/2556] Saved: ali_m5819pa19739.txt
# ✓ [172/2556] Saved: alpha_4407aba851x.txt
# ✓ [173/2556] Saved: alpha_4407aga5n3f.txt
# ✓ [174/2556] Saved: alpha_4456ba7z2a.txt
# ✓ [175/2556] Saved: alpha_4468ba8r5e.txt
# ✓ [176/2556] Saved: alpha_446ba9rbs.txt
# ✓ [177/2556] Saved: alpha_4606pa583c.txt
# ✓ [178/2556] Saved: alpha_4807pc4a29.txt
# ✓ [179/2556] Saved: alpha_4807pk6lg3.txt
# ✓ [180/2556] Saved: alpha_6380gv7n26.txt
# ✓ [181/2556] Saved: alpha_6414agv2x2n.txt
# ✓ [182/2556] Saved: alpha_6512gv2z11.txt
# ✓ [183/2556] Saved: alpha_6554gv3z18.txt
# ✓ [184/2556] Saved: alpha_6558ga2n14.txt
# ✓ [185/2556] Saved: alpha_6572gv4511.txt
# ✓ [186/2556] Saved: alpha_6996ga8131.txt
# ✓ [187/2556] Saved: alpha_7408ba1h3u.txt
# ✓ [188/2556] Saved: alpha_7408bv9u2a.txt
# ✓ [189/2556] Saved: alpha_7408ga3r16.txt
# ✓ [190/2556] Saved: alpha_7702bv2f1a.txt
# ✓ [191/2556] Saved: alpha_ba362e.txt
# ✓ [192/2556] Saved: alpha_ba4b37.txt
# ✓ [193/2556] Saved: alpha_d4184a.txt
# ✓ [194/2556] Saved: alpha_d472ba9f67.txt
# ✓ [195/2556] Saved: alpha_d604bh6t17.txt
# ✓ [196/2556] Saved: alpha_eu004y19.txt
# ✓ [197/2556] Saved: alpha_ga4g1t.txt
# ✓ [198/2556] Saved: alpha_z1948a1863413.txt
# ✓ [199/2556] Saved: alpha_z501901ta8x34.txt
# ✓ [200/2556] Saved: alps_3ja1dt005.txt
# ✓ [201/2556] Saved: alps_alp008t.txt
# ✓ [202/2556] Saved: altera_cyclonevsgefa171911n.txt
# ✓ [203/2556] Saved: altera_epm7032sli447nsbfd320925a.txt
# ✓ [204/2556] Saved: amd_215coa6ava12fs.txt
# ✓ [205/2556] Saved: amd_215nda7aka21fb.txt
# ✓ [206/2556] Saved: amd_a0750apt38afea.txt
# ✓ [207/2556] Saved: amd_a0800apt3baffa.txt
# ✓ [208/2556] Saved: amd_a095oamt3baqga0051rpt.txt
# ✓ [209/2556] Saved: amd_a1000amt3bajfa.txt
# ✓ [210/2556] Saved: amd_a1000amt3carga0123epcw.txt
# ✓ [211/2556] Saved: amd_a1200ams3baxia0105epcw.txt
# ✓ [212/2556] Saved: amd_a80386dxl25.txt
# ✓ [213/2556] Saved: amd_a80486dx.txt
# ✓ [214/2556] Saved: amd_a80486dx280nv8t.txt
# ✓ [215/2556] Saved: amd_a80486dx4100nv86.txt
# ✓ [216/2556] Saved: amd_a80486dx4100sv8b.txt
# ✓ [217/2556] Saved: amd_ad4000ka23hl9b.txt
# ✓ [218/2556] Saved: amd_ad53000ka23hjga.txt
# ✓ [219/2556] Saved: amd_ad5350jah44hmma.txt
# ✓ [220/2556] Saved: amd_ad540k0ka23hlgb.txt
# ✓ [221/2556] Saved: amd_ad68ckw0a44hlga.txt
# ✓ [222/2556] Saved: amd_ad880kxbi44jcja.txt
# ✓ [223/2556] Saved: amd_am29c983jc.txt
# ✓ [224/2556] Saved: amd_am29f040b.txt
# ✓ [225/2556] Saved: amd_am3860x40n38028660k40.txt
# ✓ [226/2556] Saved: amd_am386dx40mg03860x40d311m586.txt
# ✓ [227/2556] Saved: amd_am386sxsxl25ng80386sxl25.txt
# ✓ [228/2556] Saved: amd_am79c950akc.txt
# ✓ [229/2556] Saved: amd_am93422pc8434dmm.txt
# ✓ [230/2556] Saved: amd_palce20b8h-15jc.txt
# ✓ [231/2556] Saved: amd_radeonigp0823.txt
# ✓ [232/2556] Saved: amd_radeonigp1030.txt
# ✓ [233/2556] Saved: amd_radeonigp1040.txt
# ✓ [234/2556] Saved: ams_1438xalas34351v53.txt
# ✓ [235/2556] Saved: ams_as6031bqf2010xad.txt
# ✓ [236/2556] Saved: analog_242ad8804a.txt
# ✓ [237/2556] Saved: analog_725ar.txt
# ✓ [238/2556] Saved: analog_ad1555apz135312345.txt
# ✓ [239/2556] Saved: analog_ad1674jnz142829203231.txt
# ✓ [240/2556] Saved: analog_ad180406eqm2615x.txt
# ✓ [241/2556] Saved: analog_ad1881ajst0013.txt
# ✓ [242/2556] Saved: analog_ad1885jst.txt
# ✓ [243/2556] Saved: analog_ad1893jst.txt
# ✓ [244/2556] Saved: analog_ad1981b.txt
# ✓ [245/2556] Saved: analog_ad1981hdjstz.txt
# ✓ [246/2556] Saved: analog_ad722j49610.txt
# ✓ [247/2556] Saved: analog_ad724jr9840.txt
# ✓ [248/2556] Saved: analog_ad7523jn961961003.txt
# ✓ [249/2556] Saved: analog_ad7663ast.txt
# ✓ [250/2556] Saved: analog_ad823a16052485.txt
# ✓ [250/2556] Saved: 3com_8350019245546382402att835001.txt
# ✓ [250/2556] Saved: 3com_910a013com48076300100112700tac18710.txt
# ✓ [250/2556] Saved: 3com_910a01400763001dd1127.txt
# ✓ [250/2556] Saved: 3com_920bro340057900315189.txt
# ✓ [250/2556] Saved: 3com_920bro53com400570058636ct0027p16broadcom5904.txt
# ✓ [250/2556] Saved: 3com_920bro54005790058636.txt
# ✓ [250/2556] Saved: 3com_920bro63com40060800650401cs0037p17broadcom5904.txt
# ✓ [250/2556] Saved: 3com_920bro640060800650401.txt
# ✓ [250/2556] Saved: 3com_920st063com400664006mjc1touac0426.txt
# ✓ [250/2556] Saved: 3com_920st063com483664106mfcbsduac8227.txt
# ✓ [250/2556] Saved: 3com_920st06400664006.txt
# ✓ [250/2556] Saved: acer_m5105a4e9436ts5aa7315e.txt
# ✓ [250/2556] Saved: acer_m5105a4e9441.txt
# ✓ [250/2556] Saved: acer_m5105a4e9441ts2aa7811e.txt
# ✓ [250/2556] Saved: acer_m5105a4eaa7811e.txt
# ✓ [250/2556] Saved: acer_m6357.txt
# ✓ [250/2556] Saved: acer_m6357a1japanneo9445w50003.txt
# ✓ [250/2556] Saved: acer_mi2038y2003vi.txt
# ✓ [250/2556] Saved: acer_sioa045001as9134.txt
# ✓ [250/2556] Saved: actel_a1010bpl68c9448.txt
# ✓ [250/2556] Saved: actel_a1010bpl68c9648.txt
# ✓ [250/2556] Saved: actel_a1010bpl68c9705.txt
# ✓ [250/2556] Saved: actel_a1010pl68c8940.txt
# ✓ [250/2556] Saved: actel_a1020apl68c9037.txt
# ✓ [250/2556] Saved: actel_a1020apl84c9451.txt
# ✓ [250/2556] Saved: actel_a1020bpl4419749.txt
# ✓ [250/2556] Saved: actel_a1020bpl84c0313.txt
# ✓ [250/2556] Saved: actel_a1020bpl84c9707.txt
# ✓ [250/2556] Saved: actel_a1020bpl84c9819.txt
# ✓ [250/2556] Saved: actel_a1225apq100c9826.txt
# ✓ [250/2556] Saved: actel_a1460a1pq208c0034.txt
# ✓ [250/2556] Saved: actel_a40mx02pl4410437.txt
# ✓ [250/2556] Saved: actel_a42mx16m1pq100m0419f.txt
# ✓ [250/2556] Saved: actel_a54sx32atq14410325.txt
# ✓ [250/2556] Saved: actel_proasic3a3p250fgg2560626.txt
# ✓ [250/2556] Saved: actel_proasic3a3p250pqg2081936.txt
# ✓ [250/2556] Saved: actel_proasic3ea3pe1500pqg2081323za250471.txt
# ✓ [250/2556] Saved: actel_proasica500k050bg2720830.txt
# ✓ [250/2556] Saved: actel_proasicplusapa150pq208es.txt
# ✓ [250/2556] Saved: actel_proasicplusapa150pqg2081517r50kl.txt
# ✓ [250/2556] Saved: actel_proasicplusapa300pq2080420.txt
# ✓ [250/2556] Saved: adaptec_5800apaqea836.txt
# ✓ [250/2556] Saved: adaptec_7856taqeb712.txt
# ✓ [250/2556] Saved: adaptec_aic010flzc940.txt
# ✓ [250/2556] Saved: adaptec_aic3370pbkkb018pt.txt
# ✓ [250/2556] Saved: adaptec_aic3410pbkkb428pt.txt
# ✓ [250/2556] Saved: adaptec_aic4600lsd318ar.txt
# ✓ [250/2556] Saved: adaptec_aic560clta043.txt
# ✓ [250/2556] Saved: adaptec_aic565llsa210.txt
# ✓ [250/2556] Saved: adaptec_aic575lasa113.txt
# ✓ [250/2556] Saved: adaptec_aic580allsb209.txt
# ✓ [250/2556] Saved: adaptec_aic6251alzga313.txt
# ✓ [250/2556] Saved: adaptec_aic6260alzga145.txt
# ✓ [250/2556] Saved: adaptec_aic63600ckea809711911d350korea.txt
# ✓ [250/2556] Saved: adaptec_aic7110qgkkd603.txt
# ✓ [250/2556] Saved: adaptec_aic7770peqka438.txt
# ✓ [250/2556] Saved: adaptec_aic7850qbqwa432.txt
# ✓ [250/2556] Saved: adaptec_aic7880paqwa714.txt
# ✓ [250/2556] Saved: adaptec_aic7880pbqwab14.txt
# ✓ [250/2556] Saved: adaptec_aic7890abaqec916.txt
# ✓ [250/2556] Saved: adaptec_aic7892bbqec108.txt
# ✓ [250/2556] Saved: adaptec_aic7896naqee031.txt
# ✓ [250/2556] Saved: adaptec_aic78990aqec931.txt
# ✓ [250/2556] Saved: adaptec_aic7901xbqxb735.txt
# ✓ [250/2556] Saved: adaptec_aic_6360lckea411.txt
# ✓ [250/2556] Saved: adaptec_tbqeb92974221.txt
# ✓ [250/2556] Saved: akm_0824jbhjapan.txt
# ✓ [250/2556] Saved: akm_4385et2n925.txt
# ✓ [250/2556] Saved: akm_4430et8e523.txt
# ✓ [250/2556] Saved: akm_7755en618c.txt
# ✓ [250/2556] Saved: akm_ak4118aeq2238has.txt
# ✓ [250/2556] Saved: akm_ak41912922174ae.txt
# ✓ [250/2556] Saved: akm_ak4191eq2024vze.txt
# ✓ [250/2556] Saved: akm_ak4191eq2217vae.txt
# ✓ [250/2556] Saved: akm_ak4391eq2024vze.txt
# ✓ [250/2556] Saved: akm_ak4395eq0825ezw.txt
# ✓ [250/2556] Saved: akm_ak4458vn1425ezc.txt
# ✓ [250/2556] Saved: akm_ak4490eq1437ebe.txt
# ✓ [250/2556] Saved: akm_ak4490req2129vzj.txt
# ✓ [250/2556] Saved: akm_ak4493seo2129vzj.txt
# ✓ [250/2556] Saved: akm_ak4499eqxxxxxxxverita.txt
# ✓ [250/2556] Saved: akm_ak4499exed1234xyz.txt
# ✓ [250/2556] Saved: akm_ak4499exeq2145h7e.txt
# ✓ [250/2556] Saved: akm_ak4499exeq2236vae.txt
# ✓ [250/2556] Saved: akm_ak4499exeq2316vae.txt
# ✓ [250/2556] Saved: akm_ak4522vf0c511n.txt
# ✓ [250/2556] Saved: akm_ak4522vf1c109n.txt
# ✓ [250/2556] Saved: akm_ak4523vf064c0335n.txt
# ✓ [250/2556] Saved: akm_ak45278vq0407jaajapan.txt
# ✓ [250/2556] Saved: akm_ak4527vq0135jaajapan.txt
# ✓ [250/2556] Saved: akm_ak4528vf131b0520h.txt
# ✓ [250/2556] Saved: akm_ak4571vq0808jah.txt
# ✓ [250/2556] Saved: akm_ak4586vq0843jaa.txt
# ✓ [250/2556] Saved: akm_ak4642a643b.txt
# ✓ [250/2556] Saved: akm_ak5351vf5n644n.txt
# ✓ [250/2556] Saved: akm_ak5383vf128n0520n.txt
# ✓ [250/2556] Saved: akm_ak53858yx049e1445h.txt
# ✓ [250/2556] Saved: akm_ak5394avs003c0231n.txt
# ✓ [250/2556] Saved: akm_ak5394avs929c1927n.txt
# ✓ [250/2556] Saved: akm_ak7709vq2304sae.txt
# ✓ [250/2556] Saved: akm_ak85910610ezm.txt
# ✓ [250/2556] Saved: akm_japanak5393vs020n0150n.txt
# ✓ [250/2556] Saved: akm_veritaak4490eqxxxxxxx.txt
# ✓ [250/2556] Saved: ali_m1218.txt
# ✓ [250/2556] Saved: ali_m1219a19430ts5aa5637.txt
# ✓ [250/2556] Saved: ali_m1419a19303ts6.txt
# ✓ [250/2556] Saved: ali_m1431a29440ts6.txt
# ✓ [250/2556] Saved: ali_m1435a19412ts7.txt
# ✓ [250/2556] Saved: ali_m1445a29404ts6.txt
# ✓ [250/2556] Saved: ali_m1451a19437ts6.txt
# ✓ [250/2556] Saved: ali_m1487b19602ts6.txt
# ✓ [250/2556] Saved: ali_m1489a19602ts6.txt
# ✓ [250/2556] Saved: ali_m1511a19603ts6.txt
# ✓ [250/2556] Saved: ali_m1512a19546ts6.txt
# ✓ [250/2556] Saved: ali_m1535a10404th07.txt
# ✓ [250/2556] Saved: ali_m1541a1100mhz.txt
# ✓ [250/2556] Saved: ali_m1543cb10023tm05.txt
# ✓ [250/2556] Saved: ali_m1561a10019tb08.txt
# ✓ [250/2556] Saved: ali_m1621ai100mhz.txt
# ✓ [250/2556] Saved: ali_m5111a19449a5.txt
# ✓ [250/2556] Saved: ali_m5113a20145ts05.txt
# ✓ [250/2556] Saved: ali_m5123a9635ts62.txt
# ✓ [250/2556] Saved: ali_m5135b19841tm05.txt
# ✓ [250/2556] Saved: ali_m5143a19721ts6.txt
# ✓ [250/2556] Saved: ali_m5213na19434ts5.txt
# ✓ [250/2556] Saved: ali_m5215na29433ts5.txt
# ✓ [250/2556] Saved: ali_m5273a10411ts05.txt
# ✓ [250/2556] Saved: ali_m5283d10740tu07.txt
# ✓ [250/2556] Saved: ali_m5819pa19739.txt
# ✓ [250/2556] Saved: alpha_4407aba851x.txt
# ✓ [250/2556] Saved: alpha_4407aga5n3f.txt
# ✓ [250/2556] Saved: alpha_4456ba7z2a.txt
# ✓ [250/2556] Saved: alpha_4468ba8r5e.txt
# ✓ [250/2556] Saved: alpha_446ba9rbs.txt
# ✓ [250/2556] Saved: alpha_4606pa583c.txt
# ✓ [250/2556] Saved: alpha_4807pc4a29.txt
# ✓ [250/2556] Saved: alpha_4807pk6lg3.txt
# ✓ [250/2556] Saved: alpha_6380gv7n26.txt
# ✓ [250/2556] Saved: alpha_6414agv2x2n.txt
# ✓ [250/2556] Saved: alpha_6512gv2z11.txt
# ✓ [250/2556] Saved: alpha_6554gv3z18.txt
# ✓ [250/2556] Saved: alpha_6558ga2n14.txt
# ✓ [250/2556] Saved: alpha_6572gv4511.txt
# ✓ [250/2556] Saved: alpha_6996ga8131.txt
# ✓ [250/2556] Saved: alpha_7408ba1h3u.txt
# ✓ [250/2556] Saved: alpha_7408bv9u2a.txt
# ✓ [250/2556] Saved: alpha_7408ga3r16.txt
# ✓ [250/2556] Saved: alpha_7702bv2f1a.txt
# ✓ [250/2556] Saved: alpha_ba362e.txt
# ✓ [250/2556] Saved: alpha_ba4b37.txt
# ✓ [250/2556] Saved: alpha_d4184a.txt
# ✓ [250/2556] Saved: alpha_d472ba9f67.txt
# ✓ [250/2556] Saved: alpha_d604bh6t17.txt
# ✓ [250/2556] Saved: alpha_eu004y19.txt
# ✓ [250/2556] Saved: alpha_ga4g1t.txt
# ✓ [250/2556] Saved: alpha_z1948a1863413.txt
# ✓ [250/2556] Saved: alpha_z501901ta8x34.txt
# ✓ [250/2556] Saved: alps_3ja1dt005.txt
# ✓ [250/2556] Saved: alps_alp008t.txt
# ✓ [250/2556] Saved: altera_cyclonevsgefa171911n.txt
# ✓ [250/2556] Saved: altera_epm7032sli447nsbfd320925a.txt
# ✓ [250/2556] Saved: amd_215coa6ava12fs.txt
# ✓ [250/2556] Saved: amd_215nda7aka21fb.txt
# ✓ [250/2556] Saved: amd_a0750apt38afea.txt
# ✓ [250/2556] Saved: amd_a0800apt3baffa.txt
# ✓ [250/2556] Saved: amd_a095oamt3baqga0051rpt.txt
# ✓ [250/2556] Saved: amd_a1000amt3bajfa.txt
# ✓ [250/2556] Saved: amd_a1000amt3carga0123epcw.txt
# ✓ [250/2556] Saved: amd_a1200ams3baxia0105epcw.txt
# ✓ [250/2556] Saved: amd_a80386dxl25.txt
# ✓ [250/2556] Saved: amd_a80486dx.txt
# ✓ [250/2556] Saved: amd_a80486dx280nv8t.txt
# ✓ [250/2556] Saved: amd_a80486dx4100nv86.txt
# ✓ [250/2556] Saved: amd_a80486dx4100sv8b.txt
# ✓ [250/2556] Saved: amd_ad4000ka23hl9b.txt
# ✓ [250/2556] Saved: amd_ad53000ka23hjga.txt
# ✓ [250/2556] Saved: amd_ad5350jah44hmma.txt
# ✓ [250/2556] Saved: amd_ad540k0ka23hlgb.txt
# ✓ [250/2556] Saved: amd_ad68ckw0a44hlga.txt
# ✓ [250/2556] Saved: amd_ad880kxbi44jcja.txt
# ✓ [250/2556] Saved: amd_am29c983jc.txt
# ✓ [250/2556] Saved: amd_am29f040b.txt
# ✓ [250/2556] Saved: amd_am3860x40n38028660k40.txt
# ✓ [250/2556] Saved: amd_am3860x40n38028660k40.txt
# ✓ [250/2556] Saved: amd_am386dx40mg03860x40d311m586.txt
# ✓ [250/2556] Saved: amd_am386sxsxl25ng80386sxl25.txt
# ✓ [250/2556] Saved: amd_am79c950akc.txt
# ✓ [250/2556] Saved: amd_am93422pc8434dmm.txt
# ✓ [250/2556] Saved: amd_palce20b8h-15jc.txt
# ✓ [250/2556] Saved: amd_radeonigp0823.txt
# ✓ [250/2556] Saved: amd_radeonigp1030.txt
# ✓ [250/2556] Saved: amd_radeonigp1040.txt
# ✓ [250/2556] Saved: ams_1438xalas34351v53.txt
# ✓ [250/2556] Saved: ams_as6031bqf2010xad.txt
# ✓ [250/2556] Saved: analog_242ad8804a.txt
# ✓ [250/2556] Saved: analog_725ar.txt
# ✓ [250/2556] Saved: analog_ad1555apz135312345.txt
# ✓ [250/2556] Saved: analog_ad1674jnz142829203231.txt
# ✓ [250/2556] Saved: analog_ad180406eqm2615x.txt
# ✓ [250/2556] Saved: analog_ad1881ajst0013.txt
# ✓ [250/2556] Saved: analog_ad1885jst.txt
# ✓ [250/2556] Saved: analog_ad1893jst.txt
# ✓ [250/2556] Saved: analog_ad1893jst.txt
# ✓ [250/2556] Saved: analog_ad1981b.txt
# ✓ [250/2556] Saved: analog_ad1981hdjstz.txt
# ✓ [250/2556] Saved: analog_ad722j49610.txt
# ✓ [250/2556] Saved: analog_ad724jr9840.txt
# ✓ [250/2556] Saved: analog_ad7523jn961961003.txt
# ✓ [250/2556] Saved: analog_ad7663ast.txt
# ✓ [250/2556] Saved: analog_ad823a16052485.txt
# ✓ [251/2556] Saved: analog_ad9980kstz95.txt
# ✓ [252/2556] Saved: analog_adg506akn0222k22982.txt
# ✓ [253/2556] Saved: analog_adm211ea206.txt
# ✓ [254/2556] Saved: analog_adm241ljr.txt
# ✓ [255/2556] Saved: analog_adm691ar.txt
# ✓ [256/2556] Saved: analog_adp3186.txt
# ✓ [257/2556] Saved: analog_adp3188.txt
# ✓ [258/2556] Saved: analog_adsp2105kp40.txt
# ✓ [259/2556] Saved: analog_adsp2115kp66.txt
# ✓ [260/2556] Saved: analog_adsp2181ks133.txt
# ✓ [261/2556] Saved: analog_aduc847bsz625c21131726017861.txt
# ✓ [262/2556] Saved: analog_adv478kp66e9544.txt
# ✓ [263/2556] Saved: analog_adv7170ks9845.txt
# ✓ [264/2556] Saved: analog_adv7173kst.txt
# ✓ [265/2556] Saved: analog_c4c.txt
# ✓ [266/2556] Saved: analog_esc614.txt
# ✓ [267/2556] Saved: analogix_anx11211447scnnb238ab.txt
# ✓ [268/2556] Saved: analogix_any11211409scnna35144.txt
# ✓ [269/2556] Saved: anpec_aapw8713vq29x.txt
# ✓ [270/2556] Saved: anpec_aapw8713vs43n.txt
# ✓ [271/2556] Saved: anpec_aapw8713vx9ay.txt
# ✓ [272/2556] Saved: anpec_apa2056aak4l5.txt
# ✓ [273/2556] Saved: anpec_apa2057aajcoy.txt
# ✓ [274/2556] Saved: anpec_apa2068aj7eu.txt
# ✓ [275/2556] Saved: anpec_apa2068am17y.txt
# ✓ [276/2556] Saved: anpec_apa2614a0969.txt
# ✓ [277/2556] Saved: anpec_apl1117wh53q.txt
# ✓ [278/2556] Saved: anpec_apl1117wj11h.txt
# ✓ [279/2556] Saved: anpec_apm3095p.txt
# ✓ [280/2556] Saved: anpec_apm3106nqn42k.txt
# ✓ [281/2556] Saved: anpec_apm4550cj6ha.txt
# ✓ [282/2556] Saved: anpec_apw3007s12ad615.txt
# ✓ [283/2556] Saved: anpec_apw703stk7hn.txt
# ✓ [284/2556] Saved: anpec_apw7068aja0k.txt
# ✓ [285/2556] Saved: anpec_apw7138mm94a.txt
# ✓ [286/2556] Saved: anpec_apw7138tl50m.txt
# ✓ [287/2556] Saved: anpec_apw8713vp41c.txt
# ✓ [288/2556] Saved: anpec_apw8713vp41c2.txt
# ✓ [289/2556] Saved: anpec_apw8713vtb7t.txt
# ✓ [290/2556] Saved: anpec_apw8861vr49d.txt
# ✓ [291/2556] Saved: anpec_apw8861vvce8.txt
# ✓ [292/2556] Saved: anpec_nolabeldiagonal.txt
# ✓ [293/2556] Saved: anpec_nolabelnonumber.txt
# ✓ [449/2556] Saved: cirrus_cs163x.txt
# ✓ [450/2556] Saved: cirrus_cs41816.txt
# ✓ [451/2556] Saved: cirrus_cs42448dqz521087wabxca1821.txt
# ✓ [452/2556] Saved: cirrus_cs42516cqz122865.txt
# ✓ [453/2556] Saved: cirrus_cs4344.txt
# ✓ [454/2556] Saved: cirrus_cs4525.txt
# ✓ [455/2556] Saved: cirrus_cs494003cq2110904001.txt
# ✓ [456/2556] Saved: cirrus_cs495314cvzccwad0ly1321.txt
# ✓ [457/2556] Saved: cirrus_cs5302p.txt
# ✓ [457/2556] Saved: cirrus_cs5302p.txt
# ✓ [458/2556] Saved: cirrus_cs61584aiq3z208029.txt
# ✓ [459/2556] Saved: cirrus_ep9302.txt
# ✓ [460/2556] Saved: cirrus_ep9315cbarmtm.txt
# ✓ [461/2556] Saved: cirrus_nolabel0.txt
# ✓ [462/2556] Saved: cirrus_nolabel1.txt
# ✓ [463/2556] Saved: cmd_9324.txt
# ✓ [464/2556] Saved: cmd_9424.txt
# ✓ [465/2556] Saved: creative_ca0100iaf21a50xj.txt
# ✓ [466/2556] Saved: creative_ca0100idf2ca9ynw.txt
# ✓ [466/2556] Saved: cmd_9424.txt
# ✓ [466/2556] Saved: creative_ca0100iaf21a50xj.txt
# ✓ [466/2556] Saved: creative_ca0100idf2ca9ynw.txt
# ✓ [467/2556] Saved: creative_ca0102eat0313z2.txt
# ✓ [468/2556] Saved: creative_ca0108iat4aa4ddw.txt
# ✓ [469/2556] Saved: creative_ca20k1pag2sn0535by.txt
# ✓ [470/2556] Saved: creative_ca20k22aghf.txt
# ✓ [471/2556] Saved: creative_ct1297tat9840b.txt
# ✓ [472/2556] Saved: creative_ct1336a92.txt
# ✓ [473/2556] Saved: creative_ct1701t9409.txt
# ✓ [474/2556] Saved: creative_ct1703t9432.txt
# ✓ [475/2556] Saved: creative_ct1746b067.txt
# ✓ [476/2556] Saved: creative_ct1747opl9424gbcb.txt
# ✓ [477/2556] Saved: creative_ct1748a92bp2rt427.txt
# ✓ [478/2556] Saved: creative_ct2518daq.txt
# ✓ [479/2556] Saved: creative_ct8903daq.txt
# ✓ [480/2556] Saved: creative_ct8903mcq.txt
# ✓ [481/2556] Saved: creative_ct89080atcb0a0056.txt
# ✓ [482/2556] Saved: creative_ct8920nbq.txt
# ✓ [483/2556] Saved: creative_emu10k1ngf0037k3024.txt
# ✓ [484/2556] Saved: creative_emu10k1sefj925wff.txt
# ✓ [485/2556] Saved: creative_emu10k1sfff3042096.txt
# ✓ [486/2556] Saved: creative_emu16k1nefcreateivetech979948k3.txt
# ✓ [487/2556] Saved: creative_environmentalaudioemuk1nefcreatetivetec97.txt
# ✓ [488/2556] Saved: creative_es1371000101.txt
# ✓ [489/2556] Saved: creative_es1373000105.txt
# ✓ [490/2556] Saved: creative_ev1938.txt
# ✓ [491/2556] Saved: crystal_4299jqytab0h0214.txt
# ✓ [492/2556] Saved: crystal_cs4110cst9429n608d51.txt
# ✓ [493/2556] Saved: crystal_cs4215klutag0f0034.txt
# ✓ [494/2556] Saved: crystal_cs4215klutahuf9937.txt
# ✓ [495/2556] Saved: crystal_cs4216kleputafdc9337.txt
# ✓ [496/2556] Saved: crystal_cs4217kl.txt
# ✓ [497/2556] Saved: crystal_cs4217klctazsf9648.txt
# ✓ [498/2556] Saved: crystal_cs4218kljtawpd9634.txt
# ✓ [499/2556] Saved: crystal_cs4231aklctah0e9531.txt
# ✓ [500/2556] Saved: crystal_cs4232kqutaudp9609.txt
# ✓ [501/2556] Saved: crystal_cs4236bjqatagze9741.txt
# ✓ [502/2556] Saved: crystal_cs4236bkqatasjd9711.txt
# ✓ [503/2556] Saved: crystal_cs4236kqepttagjc9639.txt
# ✓ [504/2556] Saved: crystal_cs4237bkqataftd9708.txt
# ✓ [505/2556] Saved: crystal_cs4248kljtaizf9445.txt
# ✓ [506/2556] Saved: crystal_cs4264cqawaeyh0020.txt
# ✓ [507/2556] Saved: crystal_cs4280cmawuahg0003.txt
# ✓ [508/2556] Saved: crystal_cs4281cmepatumgc0014.txt
# ✓ [509/2556] Saved: crystal_cs4289kqtfaasc9552.txt
# ✓ [510/2556] Saved: crystal_cs4297jq.txt
# ✓ [511/2556] Saved: crystal_cs4297jqataayc9947.txt
# ✓ [512/2556] Saved: crystal_cs4297jqatatrc9918.txt
# ✓ [513/2556] Saved: crystal_cs4610cmepatakzc9730.txt
# ✓ [514/2556] Saved: crystal_cs4611cmatajac9820.txt
# ✓ [515/2556] Saved: crystal_cs4614cmepasaere9838.txt
# ✓ [516/2556] Saved: crystal_cs5503apgyajdh9343.txt
# ✓ [517/2556] Saved: crystal_cs5504bs68acwc0505.txt
# ✓ [518/2556] Saved: crystal_cs7390kpepjyakza9940.txt
# ✓ [519/2556] Saved: crystal_cs8414csgya0ya9942.txt
# ✓ [520/2556] Saved: crystal_cs8900acqz.txt
# ✓ [521/2556] Saved: crystal_cs9203cl0799287.txt
# ✓ [522/2556] Saved: crystal_cs9233cq9527.txt
# ✓ [522/2556] Saved: crystal_cs9203cl0799287.txt
# ✓ [522/2556] Saved: crystal_cs9233cq9527.txt
# ✓ [523/2556] Saved: crystal_cx4235xq3epztalse9831.txt
# ✓ [524/2556] Saved: crystal_cx4237bxq3atagme9750.txt
# ✓ [525/2556] Saved: csi_20cat28c65bk00447h.txt
# ✓ [526/2556] Saved: csi_cat28c16api2000309a.txt
# ✓ [527/2556] Saved: cypress_cy2254sc19534mfp.txt
# ✓ [528/2556] Saved: cypress_cy2255sc19641.txt
# ✓ [529/2556] Saved: cypress_cy2260sc39638.txt
# ✓ [530/2556] Saved: cypress_cy28323pvca16phi0135.txt
# ✓ [531/2556] Saved: cypress_cy28331dc811rhi0516.txt
# ✓ [532/2556] Saved: cypress_cy283430cb11twn0144.txt
# ✓ [533/2556] Saved: cypress_cy284050c3a04phi0351.txt
# ✓ [534/2556] Saved: cypress_cy284100xc.txt
# ✓ [535/2556] Saved: cypress_cy284100xcc04phi0502.txt
# ✓ [536/2556] Saved: cypress_cy29615c19724.txt
# ✓ [537/2556] Saved: cypress_cy505yc56dsd04phi0537.txt
# ✓ [538/2556] Saved: cypress_cy62256ll70pc0442e04504905.txt
# ✓ [539/2556] Saved: cypress_cy62256ll70sni0707615258phi.txt
# ✓ [540/2556] Saved: cypress_cy62256nll70pxc1725ne04627296c.txt
# ✓ [541/2556] Saved: cypress_cy6226ll70pc0422e04504905.txt
# ✓ [542/2556] Saved: cypress_cy7c10915vc0018h04505383.txt
# ✓ [543/2556] Saved: cypress_cy7c10915vc9722402032.txt
# ✓ [544/2556] Saved: cypress_cy7c10920vc9546324091.txt
# ✓ [545/2556] Saved: cypress_cy7c185a450mbcusa893343856z.txt
# ✓ [546/2556] Saved: cypress_cy7c58013a56pvxc.txt
# ✓ [547/2556] Saved: cypress_cy7c6461380nc0543.txt
# ✓ [548/2556] Saved: cypress_cy7c68013a100axc0543b04649657.txt
# ✓ [549/2556] Saved: cypress_cy7c68013a128axc0907b04612549.txt
# ✓ [550/2556] Saved: cypress_cy7c68013a128axc1605b04948103.txt
# ✓ [551/2556] Saved: cypress_cy7c68013a128axctwn1139b04103632.txt
# ✓ [552/2556] Saved: cypress_cy7c68013a128axctwn1219b04617241.txt
# ✓ [553/2556] Saved: cypress_cy7c68013a128axctwn2049b04641107c.txt
# ✓ [554/2556] Saved: cypress_cy7c68013a56pvxcb04ch1701cyp603165.txt
# ✓ [555/2556] Saved: cypress_cy92c693unc9725.txt
# ✓ [556/2556] Saved: cypress_w195bhcf16phi0132.txt
# ✓ [557/2556] Saved: cypress_w311hc16phi0110.txt
# ✓ [558/2556] Saved: cypress_w31202hc16twn0145.txt
# ✓ [559/2556] Saved: dallas_ds1225ad150nonvolatilesram0338j337647.txt
# ✓ [560/2556] Saved: dallas_ds1225ynonvolatilesram.txt
# ✓ [561/2556] Saved: dallas_ds12281200thon401latillip444.txt
# ✓ [562/2556] Saved: dallas_ds1230ab100nonvolatilesram1613c200982.txt
# ✓ [563/2556] Saved: dallas_ds1230ab150nonvolatilesram1707a416050.txt
# ✓ [564/2556] Saved: dallas_ds1230y100nonvolatilesram0246e330612.txt
# ✓ [565/2556] Saved: dallas_ds1230y100nonvolatilesram0820l487917.txt
# ✓ [566/2556] Saved: dallas_ds1230y100nonvolatilesram0820l487917philippines.txt
# ✓ [567/2556] Saved: dallas_ds1230y100nonvolatilesram1015j356238.txt
# ✓ [568/2556] Saved: dallas_ds1231ab1051nonvolatilesram18130200962.txt
# ✓ [569/2556] Saved: dallas_ds1244y70nonvolatilesram15060110553philippines.txt
# ✓ [570/2556] Saved: dallas_ds1245y100nonvolatilesram0316d1023839.txt
# ✓ [571/2556] Saved: dallas_ds1250y100nonvolatilesram0912c478301.txt
# ✓ [572/2556] Saved: dallas_ds1287arealtime.txt
# ✓ [573/2556] Saved: dallas_ds1287realtime8934b3.txt
# ✓ [574/2556] Saved: dallas_ds1287realtimeramified.txt
# ✓ [575/2556] Saved: dallas_ds12887arealtime.txt
# ✓ [620/2556] Saved: ene_kb926qfd3hhn4tcaac10082.txt
# ✓ [621/2556] Saved: ene_kb92sqp1v14xe0nc417.txt
# ✓ [622/2556] Saved: ene_kb930fa1hhneek3ac113261.txt
# ✓ [623/2556] Saved: ene_kb93220enf813186.txt
# ✓ [624/2556] Saved: ene_kb932qfa0hhn2045ac121341.txt
# ✓ [625/2556] Saved: ene_kb95420e95871523.txt
# ✓ [626/2556] Saved: ene_kb9542qbb7y1359aca180724.txt
# ✓ [627/2556] Saved: ene_kb9542qbb8x1958baca190415.txt
# ✓ [628/2556] Saved: ene_kb9542qef991513aca200220.txt
# ✓ [629/2556] Saved: ene_kb9548cf2f0z1341gca210428.txt
# ✓ [630/2556] Saved: ene_kb9548gf2f0x1367aca210507.txt
# ✓ [631/2556] Saved: ene_kb954rif3fr33133.txt
# ✓ [632/2556] Saved: ene_kq886dea1n83lz3x.txt
# ✓ [633/2556] Saved: eon_f80100hcp179q07a1047gda.txt
# ✓ [634/2556] Saved: epson_041ag80494japan.txt
# ✓ [635/2556] Saved: epson_1000000c2ph9357b.txt
# ✓ [636/2556] Saved: epson_2005e09a7218av1208gah990wa.txt
# ✓ [637/2556] Saved: epson_2005e09a7218av12108eh99262mys99217.txt
# ✓ [638/2556] Saved: epson_2005e09a7218av1835lta99069mys99728.txt
# ✓ [639/2556] Saved: epson_2005e09a7218av1850grl990kcmys99917.txt
# ✓ [640/2556] Saved: epson_2005e09a7218av1918plb99162mys99928.txt
# ✓ [641/2556] Saved: epson_armc31d5000a3g1824r377.txt
# ✓ [642/2556] Saved: epson_d1370400a2g04500524.txt
# ✓ [643/2556] Saved: epson_d1370900a1g1341r110japan.txt
# ✓ [644/2556] Saved: epson_e09a7418a2004v8186bjc9916jmys99834.txt
# ✓ [645/2556] Saved: epson_e09a926a64adgotsn9a0412011.txt
# ✓ [646/2556] Saved: epson_e09a92ga28atoknsn9a0412011.txt
# ✓ [647/2556] Saved: epson_e09a92ga32a5e8tsn9a041.txt
# ✓ [648/2556] Saved: epson_e09a92ga32a5e8tsn9a0412011.txt
# ✓ [649/2556] Saved: epson_e09a92ga42akt7tsn9a041.txt
# ✓ [650/2556] Saved: epson_e09a92ga540c6rstsn9a0412011.txt
# ✓ [651/2556] Saved: epson_e09a92ga63atq6tsn9a041.txt
# ✓ [652/2556] Saved: epson_e09a92ga63atq6tsn9a0412011.txt
# ✓ [653/2556] Saved: epson_ed1a750z1502ep60d.txt
# ✓ [654/2556] Saved: epson_ev128bbctaiwan201620nvf90500a2.txt
# ✓ [655/2556] Saved: epson_japanjotrincomf10276347.txt
# ✓ [656/2556] Saved: epson_japans1d13305f00a2f56350995.txt
# ✓ [657/2556] Saved: epson_japans1d13501f00a1f03101967.txt
# ✓ [658/2556] Saved: epson_s1c31d51japan.txt
# ✓ [659/2556] Saved: epson_s1d13305f00b1f02270509japan.txt
# ✓ [660/2556] Saved: epson_s1d13506f00a2f08200498.txt
# ✓ [661/2556] Saved: epson_s2d13v43japan.txt
# ✓ [662/2556] Saved: epson_sed1335f0b0361japan.txt
# ✓ [663/2556] Saved: epson_sed9420cac.txt
# ✓ [664/2556] Saved: epson_sli74ctf0af450.txt
# ✓ [665/2556] Saved: epson_spc2052f0a.txt
# ✓ [666/2556] Saved: epson_spc8110f0a.txt
# ✓ [667/2556] Saved: epson_v3s34400a8g09370101japan.txt
# ✓ [668/2556] Saved: espr_esp3253dexkjth1v10wwwespressifcom.txt
# ✓ [669/2556] Saved: espr_esp32dowd102017pc3w29.txt
# ✓ [670/2556] Saved: espr_esp32dowdq6392016p6w255.txt
# ✓ [671/2556] Saved: espr_esp8266ex062017pcy17.txt
# ✓ [672/2556] Saved: espr_esp8266ex152015p2p027.txt
# ✓ [673/2556] Saved: espr_esp8266ex192018tubophtu98.txt
# ✓ [674/2556] Saved: espr_esp8266ex212517pcub67.txt
# ✓ [675/2556] Saved: espr_esp8684282022h2apc3495faa0pvv872.txt
# ✓ [676/2556] Saved: espr_espwroom32ce1313211181007focid2actlespwroom52.txt
# ✓ [677/2556] Saved: etron_em636165ts7g.txt
# ✓ [678/2556] Saved: etron_em658160ts35h030505ras1741b.txt
# ✓ [679/2556] Saved: fairchild_1510sf.txt
# ✓ [680/2556] Saved: fairchild_1k24afv3040s.txt
# ✓ [681/2556] Saved: fairchild_3a36dcfd06685.txt
# ✓ [682/2556] Saved: fairchild_7acc157.txt
# ✓ [683/2556] Saved: fairchild_930.txt
# ✓ [684/2556] Saved: fairchild_a25fqfp11n60c.txt
# ✓ [685/2556] Saved: fairchild_d381ca9acf21dc.txt
# ✓ [686/2556] Saved: fairchild_db05xx22can9cc.txt
# ✓ [687/2556] Saved: fairchild_dc29adfdmf6823a.txt
# ✓ [688/2556] Saved: fairchild_dc39ctfdmf6823c.txt
# ✓ [689/2556] Saved: fairchild_dd21ac22cf100d.txt
# ✓ [690/2556] Saved: fairchild_de24ac.txt
# ✓ [691/2556] Saved: fairchild_df44akfdmf6820a.txt
# ✓ [692/2556] Saved: fairchild_dg32abfdpc5018sg.txt
# ✓ [693/2556] Saved: fairchild_p23akfds6990a.txt
# ✓ [694/2556] Saved: fairchild_p29a6eds6930a.txt
# ✓ [695/2556] Saved: fairchild_p32ahfds6986s.txt
# ✓ [696/2556] Saved: fairchild_p52az.txt
# ✓ [697/2556] Saved: fairchild_p87sp74f32.txt
# ...
# ✓ [984/2556] Saved: intel_ag24950xc3135431.txt
# ✓ [985/2556] Saved: intel_am828011uxf9145a02slb8n.txt
# ✓ [986/2556] Saved: intel_b80522p233512sl2qa.txt
# ✓ [987/2556] Saved: intel_bd81hm57slgzre22aa428.txt
# ✓ [988/2556] Saved: intel_bd82hm65slj4pe224b412.txt
# ✓ [989/2556] Saved: intel_bd82hm67slj4nx22ba907.txt
# ✓ [990/2556] Saved: intel_bd82qm67slj4me139a261.txt
# ✓ [991/2556] Saved: intel_bd8h2m65slj4pe124a810.txt
# ✓ [992/2556] Saved: intel_cg82nm10l2245c18slgxx.txt
# ✓ [993/2556] Saved: intel_d8028710l8401402.txt
# ✓ [994/2556] Saved: intel_da82562eml2065a59.txt
# ✓ [995/2556] Saved: intel_da82562et.txt
# ✓ [996/2556] Saved: intel_da82562etl549ne65.txt
# ✓ [997/2556] Saved: intel_e28f002bct80.txt
# ✓ [998/2556] Saved: intel_ep82562gl638nc54.txt
# ✓ [999/2556] Saved: intel_ep82562gtl803nb98.txt
# ✓ [1000/2556] Saved: intel_fa82537220421dgea.txt
# ✓ [1001/2556] Saved: intel_fa82537ep0442dg3a97.txt
# ✓ [1002/2556] Saved: intel_fw82801dbml7161a20sl6dnintel01.txt
# ✓ [1003/2556] Saved: intel_fw82801fbmf5283179sl7w6.txt
# ✓ [1004/2556] Saved: intel_fwe6300esbl446tb34.txt
# ✓ [1005/2556] Saved: intel_i386ab0386dx25.txt
# ✓ [1006/2556] Saved: intel_i486dx2a00486dx266.txt
# ✓ [1007/2556] Saved: intel_n28f001bxt120.txt
# ✓ [1008/2556] Saved: intel_n80930hf2l8382255.txt
# ✓ [1009/2556] Saved: intel_n82077sl.txt
# ✓ [1010/2556] Saved: intel_n82802ab8a0490341.txt
# ✓ [1011/2556] Saved: intel_p80c51bh17035y02132044sp00002.txt
# ✓ [1012/2556] Saved: intel_pcisetsb82441fxl916ea67su053intel95.txt
# ✓ [1013/2556] Saved: intel_pentium41p3ghz256.txt
# ✓ [1014/2556] Saved: intel_pentium41p3ghz256400.txt
# ✓ [1015/2556] Saved: intel_pentiumwithmmxtec.txt
# ✓ [1016/2556] Saved: intel_secretsb82441fxesv538403qq376intel95.txt
# ✓ [1017/2556] Saved: intersil_6259hrtzf004sw.txt
# ✓ [1018/2556] Saved: intersil_62773hrzw426gvb.txt
# ✓ [1019/2556] Saved: intersil_6277ahrzw810bc4.txt
# ✓ [1020/2556] Saved: intersil_6334acrzf923lfx.txt
# ✓ [1021/2556] Saved: intersil_6501acbzp631ccm.txt
# ✓ [1022/2556] Saved: intersil_651261bzv127387.txt
# ✓ [1023/2556] Saved: intersil_88738hw832sw.txt
# ✓ [1024/2556] Saved: intersil_8873hw742w5.txt
# ✓ [1025/2556] Saved: intersil_958.txt
# ✓ [1026/2556] Saved: intersil_95826hrzm422d3.txt
# ✓ [1027/2556] Saved: intersil_95836hrtzm203bc6.txt
# ✓ [1028/2556] Saved: intersil_95869hrtzx032tm.txt
# ✓ [1029/2556] Saved: intersil_ca3080ezv061260.txt
# ✓ [1030/2556] Saved: intersil_ca3080ezv06126q.txt
# ✓ [1031/2556] Saved: intersil_ca3086h1421.txt
# ✓ [1032/2556] Saved: intersil_ca3086p0436bb8t.txt
# ✓ [1033/2556] Saved: intersil_ca8030ep0049a01l.txt
# ✓ [1034/2556] Saved: intersil_h1p6601bcbpz40bb5.txt
# ✓ [1035/2556] Saved: intersil_hip6016cbh0031cbty.txt
# ✓ [1036/2556] Saved: intersil_hip6018bcbh0027ca47.txt
# ✓ [1037/2556] Saved: intersil_hip6021acb.txt
# ✓ [1038/2556] Saved: intersil_hip6021acbh0036camk.txt
# ✓ [1039/2556] Saved: intersil_hip6301cbh0036cbw5.txt
# ✓ [1040/2556] Saved: intersil_hip6301vcbp0240abu2.txt
# ✓ [1041/2556] Saved: intersil_hip6302cbp245ak4.txt
# ✓ [1042/2556] Saved: intersil_hip6601acbp144fw.txt
# ✓ [1043/2556] Saved: intersil_isl6312crzf0727bdhm.txt
# ✓ [1044/2556] Saved: intersil_isl6324acrzh0926bbbz.txt
# ✓ [1045/2556] Saved: intersil_isl6326irzh140bkh.txt
# ✓ [1046/2556] Saved: intersil_isl6364crzm119bbs.txt
# ✓ [1047/2556] Saved: intersil_isl6524cbp0140adb7.txt
# ✓ [1048/2556] Saved: intersil_isl6537crzf731xgr.txt
# ✓ [1049/2556] Saved: intersil_isl6548acrzf644wrr.txt
# ✓ [1050/2556] Saved: intersil_isl9582ocrtzw407a3z.txt
# ✓ [1051/2556] Saved: intersil_p509dnp.txt
# ✓ [1052/2556] Saved: ir_1r1220126.txt
# ✓ [1053/2556] Saved: ir_2k8880india.txt
# ✓ [1054/2556] Saved: ir_2kb880india.txt
# ✓ [1055/2556] Saved: ir_3553mc317pg9m4.txt
# ✓ [1056/2556] Saved: ir_3553mc651pa5yo.txt
# ✓ [1057/2556] Saved: ir_3859h530pz107.txt
# ✓ [1058/2556] Saved: ir_672589541221.txt
# ✓ [1059/2556] Saved: ir_6725h5031318.txt
# ✓ [1060/2556] Saved: ir_8632irfg110.txt
# ✓ [1061/2556] Saved: ir_f640nsp545j1d1p.txt
# ✓ [1062/2556] Saved: ir_goldnolabel.txt
# ✓ [1063/2556] Saved: ir_h8318j446ptp85.txt
# ✓ [1064/2556] Saved: ir_india.txt
# ✓ [1065/2556] Saved: ir_ir2113s0501.txt
# ✓ [1066/2556] Saved: ir_ir2113s05012.txt
# ✓ [1067/2556] Saved: ir_ir2153514pwds1.txt
# ✓ [1068/2556] Saved: ir_ir2153551pcp8f4.txt
# ✓ [1069/2556] Saved: ir_ir2153s741pc6v51.txt
# ✓ [1070/2556] Saved: ir_irf1407pg450w6v6.txt
# ✓ [1071/2556] Saved: ir_irfb4115p1450jn06.txt
# ✓ [1072/2556] Saved: ir_irfb7545p902ds30t.txt
# ✓ [1073/2556] Saved: ir_irfz44np006ddk5j.txt
# ✓ [1074/2556] Saved: ir_irfz44r447ka9af.txt
# ✓ [1075/2556] Saved: ir_irs23320j28pc187.txt
# ✓ [1076/2556] Saved: ir_nolabel.txt
# ✓ [1077/2556] Saved: ir_nolabel2.txt
# ✓ [1078/2556] Saved: ir_pdip14.txt
# ✓ [1079/2556] Saved: ir_rfr3806p129dd7k8.txt
# ✓ [1080/2556] Saved: isd_5116p04222232631051.txt
# ✓ [1081/2556] Saved: ite_it5570e2562317fxaea073c.txt
# ✓ [1082/2556] Saved: ite_it5571e1282127cxss18drb.txt
# ✓ [1083/2556] Saved: ite_it83902562031cxsa19uga.txt
# ✓ [1084/2556] Saved: ite_it8500e1024bxadc3whbl.txt
# ✓ [1085/2556] Saved: ite_it8502e0831jxade1yrbl.txt
# ✓ [1086/2556] Saved: ite_it8502e0930kxadecytbl.txt
# ✓ [1087/2556] Saved: ite_it8502e0942nxadc28lcl.txt
# ✓ [1088/2556] Saved: ite_it850de1031bxadcd4pbl.txt
# ✓ [1089/2556] Saved: ite_it8510e0449dxsmk0q60.txt
# ✓ [1090/2556] Saved: ite_it8510te0634gxammwlm1l.txt
# ✓ [1091/2556] Saved: ite_it8512e0838jxade3m3bl.txt
# ✓ [1092/2556] Saved: ite_it8512e0946nxadc2n6cl.txt
# ✓ [1093/2556] Saved: ite_it8517e1234hxasc03pc.txt
# ✓ [1094/2556] Saved: ite_it8518e1251hxasc08jd.txt
# ✓ [1095/2556] Saved: ite_it8519e1117cxadce7dd.txt
# ✓ [1096/2556] Saved: ite_it8519e1153cxadceubd.txt
# ✓ [1097/2556] Saved: ite_it8528e1241axsecz1ya.txt
# ✓ [1098/2556] Saved: ite_it8528e1403exssc0a8b.txt
# ✓ [1099/2556] Saved: ite_it8528e1422fxasc1dha.txt
# ✓ [1100/2556] Saved: ite_it8528e1541fxas04qda.txt
# ✓ [1101/2556] Saved: ite_it8528e1639fxas06cqa.txt
# ✓ [1102/2556] Saved: ite_it8561e1246hxsac065c.txt
# ✓ [1103/2556] Saved: ite_it8570e1018axadc2cld.txt
# ✓ [1104/2556] Saved: ite_it8572e1107axadce1ub.txt
# ✓ [1105/2556] Saved: ite_it8587e1301exsecz1yb.txt
# ✓ [1106/2556] Saved: ite_it8718fs0745fxszms5sbl.txt
# ✓ [1107/2556] Saved: ite_it8755e1105jxsac03ndl.txt
# ✓ [1108/2556] Saved: ite_it8758e1119bxgac013e.txt
# ✓ [1109/2556] Saved: ite_it88931034bxszc15ga.txt
# ✓ [1110/2556] Saved: ite_it8995e1281536cxssc4g5a.txt
# ✓ [1111/2556] Saved: jl_ac6965e4.txt
# ✓ [1112/2556] Saved: jrc_207372050.txt
# ✓ [1113/2556] Saved: jrc_45659022m.txt
# ✓ [1114/2556] Saved: kia_78d05f528.txt
# ✓ [1115/2556] Saved: lenovo_54y9009200g02efg1036japan1019eg1f0824aad.txt
# ✓ [1116/2556] Saved: lenovo_it5576e1282034cxask29fb.txt
# ✓ [1117/2556] Saved: lenovo_it822681281828ux6515yxal002.txt
# ✓ [1118/2556] Saved: lenovo_it8226e123i632bxazc15kal0d1.txt
# ✓ [1119/2556] Saved: lenovo_it8226e1281628bxaeczy0a.txt
# ✓ [1120/2556] Saved: lenovo_it8226e1281628bxaeczy0al001.txt
# ✓ [1121/2556] Saved: lenovo_it8226e1281632bxazc16kal001.txt
# ✓ [1122/2556] Saved: lenovo_it8226e1921909bxas16nzal003.txt
# ✓ [1123/2556] Saved: lenovo_it8226e1921921bxas16zaal003.txt
# ✓ [1124/2556] Saved: lenovo_it8226e1921949bxas17snal003.txt
# ✓ [1125/2556] Saved: lenovo_it8226e1949bxas17snal003.txt
# ✓ [1210/2556] Saved: marvell_88e60658laj1ahwjm2520702a1p.txt
# ✓ [1211/2556] Saved: marvell_88e6065blaj1ahwjm2520702a1pessfftw.txt
# ✓ [1212/2556] Saved: marvell_88e6083lgr1d1a33211110b0ptw.txt
# ✓ [1213/2556] Saved: marvell_88e6097tah1q3c3781209941a2p.txt
# ✓ [1214/2556] Saved: marvell_88e6172tfj2p1sr9904jw1445a1ptw.txt
# ✓ [1215/2556] Saved: marvell_88e6172tfj2pktg230a01jw1836a1ptw.txt
# ✓ [1216/2556] Saved: marvell_88e6172tfj2pmuu170a05jw1905a1ptw.txt
# ✓ [1217/2556] Saved: marvell_88e6176tfj2ph8w14004jw2112a1ptw.txt
# ✓ [1218/2556] Saved: marvell_88e6185lkj1q0bc89101jw1920a2ptw.txt
# ✓ [1219/2556] Saved: marvell_88e6350rtfj2p4ng2201jw1604a10cn.txt
# ✓ [1220/2556] Saved: marvell_88e635drtfj2p2s512021224a1ptw.txt
# ✓ [1221/2556] Saved: marvell_88e8001lkjq30995110345a3p.txt
# ✓ [1222/2556] Saved: marvell_88e8056nnc1wg8066020824b0ssg.txt
# ✓ [1223/2556] Saved: marvell_88ec060nn82nkv09403jw1411a0ccn.txt
# ✓ [1224/2556] Saved: marvell_88em8183.txt
# ✓ [1225/2556] Saved: marvell_88i6522lg01wc47260b00531a3s.txt
# ✓ [1226/2556] Saved: marvell_88i6724shkj1ypm144970802b0ptw.txt
# ✓ [1227/2556] Saved: marvell_88i8826eban2ypm141250751a3pstw.txt
# ✓ [1228/2556] Saved: marvell_88q6113.txt
# ✓ [1229/2556] Saved: marvell_88w8363cbemft16811a10751a5ptw.txt
# ✓ [1230/2556] Saved: marvell_88w8777.txt
# ✓ [1231/2556] Saved: marvell_88x7120.txt
# ✓ [1232/2556] Saved: marvell_gt64260880fp6844100648c0etw.txt
# ✓ [1233/2556] Saved: marvell_qa15021a20437a3ptaiwan.txt
# ✓ [1234/2556] Saved: matsushita_528000m54515p.txt
# ✓ [1235/2556] Saved: matsushita_956an78m09.txt
# ✓ [1236/2556] Saved: matsushita_an1358.txt
# ✓ [1237/2556] Saved: matsushita_an17000A312A449E.txt
# ✓ [1238/2556] Saved: matsushita_an183103.txt
# ✓ [1239/2556] Saved: matsushita_an239q579.txt
# ✓ [1240/2556] Saved: matsushita_an295094.txt
# ✓ [1241/2556] Saved: matsushita_an331228.txt
# ✓ [1242/2556] Saved: matsushita_an5131593.txt
# ✓ [1243/2556] Saved: matsushita_an5720430n.txt
# ✓ [1244/2556] Saved: matsushita_an5900396.txt
# ✓ [1245/2556] Saved: matsushita_an6256279.txt
# ✓ [1246/2556] Saved: matsushita_an6341n4d7.txt
# ✓ [1247/2556] Saved: matsushita_an6362162.txt
# ✓ [1248/2556] Saved: matsushita_an6362243.txt
# ✓ [1249/2556] Saved: matsushita_an7254610.txt
# ✓ [1250/2556] Saved: matsushita_an727495.txt
# ✓ [1251/2556] Saved: matsushita_an73104d4.txt
# ✓ [1252/2556] Saved: matsushita_an7410m664.txt
# ✓ [1253/2556] Saved: matsushita_an7470japan380.txt
# ✓ [1254/2556] Saved: matsushita_an8090179a.txt
# ✓ [1255/2556] Saved: matsushita_an90c22328.txt
# ✓ [1256/2556] Saved: matsushita_mn120128.txt
# ✓ [1257/2556] Saved: matsushita_mn1220107.txt
# ✓ [1258/2556] Saved: matsushita_mn1287eav.txt
# ✓ [1259/2556] Saved: matsushita_mn1400vl49.txt
# ✓ [1260/2556] Saved: matsushita_mn1404bc8d.txt
# ✓ [1261/2556] Saved: matsushita_mn1405vm10.txt
# ✓ [1262/2556] Saved: matsushita_mn1405vm1n.txt
# ✓ [1263/2556] Saved: matsushita_mn4011b004.txt
# ✓ [1264/2556] Saved: matsushita_mn4164p12a9d4y.txt
# ✓ [1265/2556] Saved: matsushita_mn6040a6d.txt
# ✓ [1266/2556] Saved: matsushita_mn614207.txt
# ✓ [1267/2556] Saved: matsushita_mn614765.txt
# ✓ [1268/2556] Saved: matsushita_mn6165maa42.txt
# ✓ [1269/2556] Saved: matsushita_mn6168via538.txt
# ✓ [1270/2556] Saved: matsushita_mn6168vibmatsushita423.txt
# ✓ [1271/2556] Saved: matsushita_mn6168vih4d7.txt
# ✓ [1272/2556] Saved: matsushita_mn6631a142.txt
# ✓ [1273/2556] Saved: matsushita_mn6632a548.txt
# ✓ [1274/2556] Saved: matsushita_mn73200scq.txt
# ✓ [1275/2556] Saved: matsushita_mn900389.txt
# ✓ [1276/2556] Saved: matsushita_mni2080d.txt
# ✓ [1277/2556] Saved: maxim_151betj140ittt.txt
# ✓ [1278/2556] Saved: maxim_1617mee002.txt
# ✓ [1279/2556] Saved: maxim_17033gtl006ntaq.txt
# ✓ [1280/2556] Saved: maxim_1705ggtl037jtdt.txt
# ✓ [1281/2556] Saved: maxim_17113etl152btui.txt
# ✓ [1282/2556] Saved: maxim_1715eei0313.txt
# ✓ [1283/2556] Saved: maxim_17480gtl952itao.txt
# ✓ [1284/2556] Saved: maxim_17511gtl218beaa.txt
# ✓ [1285/2556] Saved: maxim_8731aeti805ntgm.txt
# ✓ [1286/2556] Saved: maxim_8731aeti826itju.txt
# ✓ [1287/2556] Saved: maxim_9789aetj936nehc.txt
# ✓ [1288/2556] Saved: maxim_9789aetjd15nemu.txt
# ✓ [1289/2556] Saved: maxim_icl7106cpl9406n.txt
# ✓ [1290/2556] Saved: maxim_icm7217ipi9828.txt
# ✓ [1291/2556] Saved: maxim_max1044cpaplus.txt
# ✓ [1292/2556] Saved: maxim_max1480acpi0807.txt
# ✓ [1293/2556] Saved: maxim_max15119gtm315bsm0qeh.txt
# ✓ [1294/2556] Saved: maxim_max15119stm22725m90th.txt
# ✓ [1295/2556] Saved: maxim_max1634aeai0310.txt
# ✓ [1296/2556] Saved: maxim_max17077etm821ndetbaqq3.txt
# ✓ [1297/2556] Saved: maxim_max1718eei0305a.txt
# ✓ [1298/2556] Saved: maxim_max176bcpa0028.txt
# ✓ [1299/2556] Saved: maxim_max190bcwg.txt
